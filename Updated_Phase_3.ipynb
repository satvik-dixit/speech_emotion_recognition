# %% [markdown]
# # Phase 3

# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import soundfile as sf
import librosa
import os
from glob import glob
import torch

# %%
! pip install -q kaggle

from google.colab import files
files.upload()

# Name directory
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-a659ac57-9a86-4aa7-bfa3-8feb2e55b7fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a659ac57-9a86-4aa7-bfa3-8feb2e55b7fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# CREMA-D Dataset

! kaggle datasets download -d ejlok1/cremad
! unzip cremad.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AudioWAV/1031_DFA_DIS_XX.wav
#   inflating: AudioWAV/1031_DFA_FEA_XX.wav
#   inflating: AudioWAV/1031_DFA_HAP_XX.wav
#   inflating: AudioWAV/1031_DFA_NEU_XX.wav
#   inflating: AudioWAV/1031_DFA_SAD_XX.wav
#   inflating: AudioWAV/1031_IEO_ANG_HI.wav
#   inflating: AudioWAV/1031_IEO_ANG_LO.wav
#   inflating: AudioWAV/1031_IEO_ANG_MD.wav
#   inflating: AudioWAV/1031_IEO_DIS_HI.wav
#   inflating: AudioWAV/1031_IEO_DIS_LO.wav
#   inflating: AudioWAV/1031_IEO_DIS_MD.wav
#   inflating: AudioWAV/1031_IEO_FEA_HI.wav
#   inflating: AudioWAV/1031_IEO_FEA_LO.wav
#   inflating: AudioWAV/1031_IEO_FEA_MD.wav
#   inflating: AudioWAV/1031_IEO_HAP_HI.wav
#   inflating: AudioWAV/1031_IEO_HAP_LO.wav
#   inflating: AudioWAV/1031_IEO_HAP_MD.wav
#   inflating: AudioWAV/1031_IEO_NEU_XX.wav
#   inflating: AudioWAV/1031_IEO_SAD_HI.wav
#   inflating: AudioWAV/1031_IEO_SAD_LO.wav
#   inflating: AudioWAV/1031_IEO_SAD_MD.wav
#   inflating: AudioWAV/1031_IOM_ANG_XX.wav
#   inflating: AudioWAV/1031_IOM_DIS_XX.wav
#   inflating: AudioWAV/1031_IOM_FEA_XX.wav
#   inflating: AudioWAV/1031_IOM_HAP_XX.wav
#   inflating: AudioWAV/1031_IOM_NEU_XX.wav
#   inflating: AudioWAV/1031_IOM_SAD_XX.wav
#   inflating: AudioWAV/1031_ITH_ANG_XX.wav
#   inflating: AudioWAV/1031_ITH_DIS_XX.wav
#   inflating: AudioWAV/1031_ITH_FEA_XX.wav
#   inflating: AudioWAV/1031_ITH_HAP_XX.wav
#   inflating: AudioWAV/1031_ITH_NEU_XX.wav
#   inflating: AudioWAV/1031_ITH_SAD_XX.wav
#   inflating: AudioWAV/1031_ITS_ANG_XX.wav
#   inflating: AudioWAV/1031_ITS_DIS_XX.wav
#   inflating: AudioWAV/1031_ITS_FEA_XX.wav
#   inflating: AudioWAV/1031_ITS_HAP_XX.wav
#   inflating: AudioWAV/1031_ITS_NEU_XX.wav
#   inflating: AudioWAV/1031_ITS_SAD_XX.wav
#   inflating: AudioWAV/1031_IWL_ANG_XX.wav
#   inflating: AudioWAV/1031_IWL_DIS_XX.wav
#   inflating: AudioWAV/1031_IWL_FEA_XX.wav
#   inflating: AudioWAV/1031_IWL_HAP_XX.wav
#   inflating: AudioWAV/1031_IWL_NEU_XX.wav
#   inflating: AudioWAV/1090_ITS_NEU_XX.wav
#   inflating: AudioWAV/1090_ITS_SAD_XX.wav
#   inflating: AudioWAV/1090_IWL_ANG_XX.wav
#   inflating: AudioWAV/1090_IWL_DIS_XX.wav
#   inflating: AudioWAV/1090_IWL_FEA_XX.wav
#   inflating: AudioWAV/1090_IWL_HAP_XX.wav
#   inflating: AudioWAV/1090_IWL_NEU_XX.wav
#   inflating: AudioWAV/1090_IWL_SAD_XX.wav
#   inflating: AudioWAV/1090_IWW_ANG_XX.wav
#   inflating: AudioWAV/1090_IWW_DIS_XX.wav
#   inflating: AudioWAV/1090_IWW_FEA_XX.wav
#   inflating: AudioWAV/1090_IWW_HAP_XX.wav
#   inflating: AudioWAV/1090_IWW_NEU_XX.wav
#   inflating: AudioWAV/1090_IWW_SAD_XX.wav
#   inflating: AudioWAV/1090_MTI_ANG_XX.wav
#   inflating: AudioWAV/1090_MTI_DIS_XX.wav
#   inflating: AudioWAV/1090_MTI_FEA_XX.wav
#   inflating: AudioWAV/1090_MTI_HAP_XX.wav
#   inflating: AudioWAV/1090_MTI_NEU_XX.wav
#   inflating: AudioWAV/1090_MTI_SAD_XX.wav
#   inflating: AudioWAV/1090_TAI_ANG_XX.wav
#   inflating: AudioWAV/1090_TAI_DIS_XX.wav
#   inflating: AudioWAV/1090_TAI_FEA_XX.wav
#   inflating: AudioWAV/1090_TAI_HAP_XX.wav
#   inflating: AudioWAV/1090_TAI_NEU_XX.wav
#   inflating: AudioWAV/1090_TAI_SAD_XX.wav
#   inflating: AudioWAV/1090_TIE_ANG_XX.wav
#   inflating: AudioWAV/1090_TIE_DIS_XX.wav
#   inflating: AudioWAV/1090_TIE_FEA_XX.wav
#   inflating: AudioWAV/1090_TIE_HAP_XX.wav
#   inflating: AudioWAV/1090_TIE_NEU_XX.wav
#   inflating: AudioWAV/1090_TIE_SAD_XX.wav
#   inflating: AudioWAV/1090_TSI_ANG_XX.wav
#   inflating: AudioWAV/1090_TSI_DIS_XX.wav
#   inflating: AudioWAV/1090_TSI_FEA_XX.wav
#   inflating: AudioWAV/1090_TSI_HAP_XX.wav
#   inflating: AudioWAV/1090_TSI_NEU_XX.wav
#   inflating: AudioWAV/1090_TSI_SAD_XX.wav
#   inflating: AudioWAV/1090_WSI_ANG_XX.wav
#   inflating: AudioWAV/1090_WSI_DIS_XX.wav
#   inflating: AudioWAV/1090_WSI_FEA_XX.wav
#   inflating: AudioWAV/1090_WSI_HAP_XX.wav
#   inflating: AudioWAV/1090_WSI_NEU_XX.wav
#   inflating: AudioWAV/1090_WSI_SAD_XX.wav
#   inflating: AudioWAV/1091_DFA_ANG_XX.wav
#   inflating: AudioWAV/1091_DFA_DIS_XX.wav
#   inflating: AudioWAV/1091_DFA_FEA_XX.wav
#   inflating: AudioWAV/1091_DFA_HAP_XX.wav
#   inflating: AudioWAV/1091_DFA_NEU_XX.wav
#   inflating: AudioWAV/1091_DFA_SAD_XX.wav
#   inflating: AudioWAV/1091_IEO_ANG_HI.wav
#   inflating: AudioWAV/1091_TAI_DIS_XX.wav
#   inflating: AudioWAV/1091_TAI_FEA_XX.wav
#   inflating: AudioWAV/1091_TAI_HAP_XX.wav
#   inflating: AudioWAV/1091_TAI_NEU_XX.wav
#   inflating: AudioWAV/1091_TAI_SAD_XX.wav
#   inflating: AudioWAV/1091_TIE_ANG_XX.wav
#   inflating: AudioWAV/1091_TIE_DIS_XX.wav
#   inflating: AudioWAV/1091_TIE_FEA_XX.wav
#   inflating: AudioWAV/1091_TIE_HAP_XX.wav
#   inflating: AudioWAV/1091_TIE_NEU_XX.wav
#   inflating: AudioWAV/1091_TIE_SAD_XX.wav
#   inflating: AudioWAV/1091_TSI_ANG_XX.wav
#   inflating: AudioWAV/1091_TSI_DIS_XX.wav
#   inflating: AudioWAV/1091_TSI_FEA_XX.wav
#   inflating: AudioWAV/1091_TSI_HAP_XX.wav
#   inflating: AudioWAV/1091_TSI_NEU_XX.wav
#   inflating: AudioWAV/1091_TSI_SAD_XX.wav
#   inflating: AudioWAV/1091_WSI_ANG_XX.wav
#   inflating: AudioWAV/1091_WSI_DIS_XX.wav
#   inflating: AudioWAV/1091_WSI_FEA_XX.wav
#   inflating: AudioWAV/1091_WSI_HAP_XX.wav
#   inflating: AudioWAV/1091_WSI_NEU_XX.wav
#   inflating: AudioWAV/1091_WSI_SAD_XX.wav

# %% [markdown]
# # Phase 1: Loading and resampling audio files

# %%
# Defining function for loading and resampling audio files

# Processing audio files
audio_files_crema_d = glob(os.path.join('/content/AudioWAV','*.wav'))

def load_audio_files(audio_files, resampling_frequency=16000, audio_list=None):
    '''
    Loads and resamples audio files 
    
    Parameters
    ------------
    audio_files: string
        The paths of the wav files 
    resampling_frequency: integer
        The frequency which all audios will be resampled to
    audio_list: list of torch arrays of audios to which more audios need too be added, empty by default

    Returns
    ------------
    audio_list: list of torch arrays
        A list of torch arrays, one array for each audio file
        
    '''

    # Making audio_list
    if audio_list is None:
      audio_list = []

    # Resampling
    for audio in audio_files:
        signal, fs = librosa.load(audio, sr=resampling_frequency)
        audio_list.append(torch.from_numpy(signal))
        
    return audio_list

# %%
audio_files_crema_d = glob(os.path.join('/content/AudioWAV','*.wav'))

# Using load_audio_files function
audio_list_crema_d = load_audio_files(audio_files_crema_d, resampling_frequency=16000)
print('number of audio files: {}'.format(len(audio_list_crema_d)))
print(audio_list_crema_d[0].shape)
# Out:
# number of audio files: 7442
# torch.Size([43777])

# %% [markdown]
# # Phase 2: Embedding Extraction

# %%
# !pip install speechbrain
# !pip install transformers
# !git clone https://github.com/GasserElbanna/serab-byols.git
# !python3 -m pip install -e ./serab-byols

# !pip install tqdm==4.60.0
# !pip install opensmile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: speechbrain in /usr/local/lib/python3.7/dist-packages (0.5.12)
# Requirement already satisfied: torch<=1.11,>=1.7 in /usr/local/lib/python3.7/dist-packages (from speechbrain) (1.11.0+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from speechbrain) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from speechbrain) (1.21.6)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from speechbrain) (0.8.1)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.7/dist-packages (from speechbrain) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from speechbrain) (21.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from speechbrain) (0.1.96)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from speechbrain) (4.60.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (from speechbrain) (0.11.0+cu113)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from speechbrain) (1.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<=1.11,>=1.7->speechbrain) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain) (4.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain) (3.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->speechbrain) (3.0.9)
# Requirement already satisfied: ruamel.yaml>=0.17.8 in /usr/local/lib/python3.7/dist-packages (from hyperpyyaml->speechbrain) (0.17.21)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml>=0.17.8->hyperpyyaml->speechbrain) (0.2.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub->speechbrain) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub->speechbrain) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub->speechbrain) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub->speechbrain) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub->speechbrain) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.8.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.60.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# fatal: destination path 'serab-byols' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/serab-byols
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (0.8.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (1.21.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (1.11.0+cu113)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (0.11.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (4.60.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (1.9)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (1.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.7/dist-packages (from serab-byols==0.0.0) (0.4.1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (21.3)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (0.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (0.10.3.post1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (1.4.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (1.6.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa->serab-byols==0.0.0) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->serab-byols==0.0.0) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->serab-byols==0.0.0) (0.34.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa->serab-byols==0.0.0) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->serab-byols==0.0.0) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->serab-byols==0.0.0) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->serab-byols==0.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->serab-byols==0.0.0) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->serab-byols==0.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->serab-byols==0.0.0) (2.10)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa->serab-byols==0.0.0) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->serab-byols==0.0.0) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa->serab-byols==0.0.0) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->serab-byols==0.0.0) (2.21)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->serab-byols==0.0.0) (4.1.1)
# Installing collected packages: serab-byols
#   Attempting uninstall: serab-byols
#     Found existing installation: serab-byols 0.0.0
#     Can't uninstall 'serab-byols'. No files were found to uninstall.
#   Running setup.py develop for serab-byols
# Successfully installed serab-byols-0.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm==4.60.0 in /usr/local/lib/python3.7/dist-packages (4.60.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opensmile in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: audinterface>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from opensmile) (0.8.1)
# Requirement already satisfied: audobject>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from opensmile) (0.7.1)
# Requirement already satisfied: audformat<2.0.0,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from audinterface>=0.7.0->opensmile) (0.14.3)
# Requirement already satisfied: audresample<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from audinterface>=0.7.0->opensmile) (1.1.0)
# Requirement already satisfied: audiofile>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.1.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (6.0)
# Requirement already satisfied: audeer<2.0.0,>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.18.0)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.0)
# Requirement already satisfied: pandas!=1.3.0,!=1.3.1,!=1.3.2,!=1.3.3,!=1.4.0,>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.3.5)
# Requirement already satisfied: iso3166 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (2.0.2)
# Requirement already satisfied: iso-639 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (0.4.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from audeer<2.0.0,>=1.18.0->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (4.60.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (0.10.3.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.21.6)
# Requirement already satisfied: sox in /usr/local/lib/python3.7/dist-packages (from audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from audobject>=0.6.1->opensmile) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas!=1.3.0,!=1.3.1,!=1.3.2,!=1.3.3,!=1.4.0,>=1.1.5->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas!=1.3.0,!=1.3.1,!=1.3.2,!=1.3.3,!=1.4.0,>=1.1.5->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas!=1.3.0,!=1.3.1,!=1.3.2,!=1.3.3,!=1.4.0,>=1.1.5->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.15.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface>=0.7.0->opensmile) (2.21)

# %%
from tqdm import tqdm
import serab_byols
import opensmile
from transformers import Wav2Vec2Model, HubertModel
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Defining the functions

# %%
def audio_embeddings_model(model_name):
  '''
  Generates model for embedding extraction 
  
  Parameters
  ------------
  mode_name: string
      The model to used, could be 'wav2vec', 'hubert' or 'hybrid_byols'

  Returns
  ------------
  model: object

  '''
  if model_name=='wav2vec2':
    model_hub = 'facebook/wav2vec2-large-960h-lv60-self'
    model = Wav2Vec2Model.from_pretrained(model_hub)
  elif model_name=='hubert':
    model_hub = 'facebook/hubert-xlarge-ll60k'
    model = HubertModel.from_pretrained(model_hub)
  elif model_name=='hybrid_byols':
    model_name = 'cvt'
    checkpoint_path = "serab-byols/checkpoints/cvt_s1-d1-e64_s2-d1-e256_s3-d1-e512_BYOLAs64x96-osandbyolaloss6373-e100-bs256-lr0003-rs42.pth"
    model = serab_byols.load_model(checkpoint_path, model_name)
  elif model_name=='compare':
    model = opensmile.Smile(
        feature_set=opensmile.FeatureSet.ComParE_2016,
        feature_level=opensmile.FeatureLevel.Functionals,
    )
  elif model_name=='egemaps':
    model = opensmile.Smile(
        feature_set=opensmile.FeatureSet.eGeMAPSv02,
        feature_level=opensmile.FeatureLevel.Functionals,
    )
  return model


def audio_embeddings(audio_list, model_name, model, sampling_rate=16000):
  '''
  Loads and resamples audio files 
  
  Parameters
  ------------
  audio_list: list of arrays
      A list of arrays, one array for each audio file
  model_name: string
      The model to used, could be 'wav2vec', 'hubert' or 'hybrid_byols'
  model: object
      The model generated by audio_embeddings_model function
  n_feats: int
      The number of features of each audio file, 6373 for 'compare' and 88 for 'egemaps'

  Returns
  ------------
  embeddings_array: torch array
      The array containg embeddings of all audio_files, dimension (number of audio files × n_feats)
      
  '''
  if model_name=='hybrid_byols':
    embeddings_array = serab_byols.get_scene_embeddings(audio_list, model)
  else:
    embeddings_list = []
    for i in tqdm(range(len(audio_list))):
      if model_name=='wav2vec2' or model_name=='hubert':
        embeddings = model(audio_list[i].reshape(1,-1)).last_hidden_state.mean(1)
        embeddings_list.append(embeddings[0])
      elif model_name=='compare' or model_name=='egemaps':
        embeddings = model.process_signal(audio_list[i], sampling_rate)
        embeddings_list.append(torch.tensor(embeddings.values[0], dtype=torch.float32))
    embeddings_array = torch.stack(embeddings_list)
  return embeddings_array

# %% [markdown]
# ## 1. Wav2vec 2.0

# %%
model = audio_embeddings_model(model_name='wav2vec2')
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h-lv60-self were not used when initializing Wav2Vec2Model: ['lm_head.bias', 'lm_head.weight']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
embeddings_array_wav2vec = audio_embeddings(audio_list_crema_d[:2], model_name='wav2vec2', model=model)
print(embeddings_array_wav2vec.shape)
# Out:
# 100%|██████████| 2/2 [00:07<00:00,  3.76s/it]
# torch.Size([2, 1024])

# %% [markdown]
# ## 2. Hubert

# %%
model = audio_embeddings_model(model_name='hubert')
# Out:
# Downloading:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.59G [00:00<?, ?B/s]

# %%
embeddings_array_hubert = audio_embeddings(audio_list_crema_d[:2], model_name='hubert', model=model)
# Out:
# 100%|██████████| 2/2 [00:14<00:00,  7.05s/it]

# %%
print(embeddings_array_hubert.shape)
print(embeddings_array_hubert)
# Out:
# torch.Size([2, 1280])
# tensor([[ 0.0828, -0.0093,  0.0158,  ...,  0.0499, -0.0047, -0.0357],
#         [ 0.0589,  0.0189,  0.0697,  ..., -0.1487, -0.0101, -0.0034]],
#        grad_fn=<StackBackward0>)

# %% [markdown]
# ## 3. Hybrid BYOL-S

# %%
model = audio_embeddings_model(model_name='hybrid_byols')

# %%
embeddings_array_byols = audio_embeddings(audio_list_crema_d, model_name='hybrid_byols', model=model)
# Out:
# Generating Embeddings...: 100%|██████████| 7442/7442 [05:02<00:00, 24.62it/s]

# %%
print(embeddings_array_byols.shape)
print(embeddings_array_byols)
# Out:
# torch.Size([7442, 2048])
# tensor([[ 4.6005,  3.3193,  1.6502,  ...,  3.0076,  0.7459,  3.8370],
#         [ 5.1524,  3.6945,  1.3245,  ...,  4.2870, -0.1191,  5.4642],
#         [ 3.5540,  3.3808,  1.4869,  ...,  3.0218, -1.3578,  3.7170],
#         ...,
#         [ 5.3331,  3.4665,  1.4162,  ...,  2.9429, -1.9563,  4.2440],
#         [ 6.1522,  3.4810,  2.0665,  ...,  2.4415,  0.8819,  3.7001],
#         [ 2.7747,  2.9199,  1.9036,  ...,  2.9964, -0.0655,  4.2349]])

# %% [markdown]
# ## 4. openSMILE: ComParE_2016

# %%
model = audio_embeddings_model(model_name='compare')
embeddings_array_compare = audio_embeddings(audio_list_crema_d, model_name='compare', model=model)
print(embeddings_array_compare.shape)
# Out:
# 100%|██████████| 7442/7442 [11:40<00:00, 10.62it/s]
# torch.Size([7442, 6373])

# %%
print(embeddings_array_compare)
# Out:
# tensor([[1.2293e+00, 3.3835e-01, 1.8797e-02,  ..., 5.5680e+01, 1.1914e+02,
#          6.0391e+01],
#         [3.5037e+00, 4.5392e-01, 6.8259e-03,  ..., 6.2398e+01, 1.1730e+02,
#          6.2005e+01],
#         [5.2160e-01, 2.8049e-01, 4.0650e-03,  ..., 3.7978e+01, 8.8560e+01,
#          4.5760e+01],
#         ...,
#         [1.1129e+00, 4.2487e-01, 2.8497e-01,  ..., 3.7853e+01, 9.3689e+01,
#          7.5141e+01],
#         [8.0568e-01, 5.7812e-01, 1.2500e-01,  ..., 4.4861e+01, 1.0203e+02,
#          4.5219e+01],
#         [9.5088e-01, 3.9331e-01, 7.1130e-02,  ..., 5.4985e+01, 1.1222e+02,
#          4.8933e+01]])

# %% [markdown]
# ## 5. openSMILE: eGeMAPSv02

# %%
model = audio_embeddings_model(model_name='egemaps')
embeddings_array_egemaps = audio_embeddings(audio_list_crema_d, model_name='egemaps', model=model)
print(embeddings_array_egemaps.shape)
# Out:
# 100%|██████████| 7442/7442 [12:08<00:00, 10.22it/s]
# torch.Size([7442, 88])

# %%
print(embeddings_array_egemaps)
# Out:
# tensor([[ 2.6969e+01,  1.7750e-01,  2.0970e+01,  ...,  4.1600e-01,
#           3.8624e-01, -2.9704e+01],
#         [ 2.7472e+01,  2.2636e-01,  2.4899e+01,  ...,  2.0400e-01,
#           1.5292e-01, -2.3412e+01],
#         [ 3.3227e+01,  2.5948e-02,  3.2583e+01,  ...,  7.4333e-01,
#           2.8312e-01, -3.7683e+01],
#         ...,
#         [ 2.7446e+01,  7.9522e-02,  2.5437e+01,  ...,  5.9000e-01,
#           3.7417e-02, -2.9595e+01],
#         [ 3.7473e+01,  1.1554e-01,  3.3526e+01,  ...,  3.9250e-01,
#           3.8906e-01, -3.1436e+01],
#         [ 3.3596e+01,  5.2283e-02,  3.2301e+01,  ...,  2.8333e-01,
#           2.5882e-01, -3.5557e+01]])

# %% [markdown]
# <B>Problems:</B>
# - Colab crashes when using hubert or wav2vec for all 200 audio files, works well for a list of 20 audio files for wav2vec and a list of 5 audio files for hubert

# %% [markdown]
# # Phase 3: Downstream Task - Speech Emotion Recognotion

# %% [markdown]
# ## Extracting labels and speaker ID

# %%
speakers = []
labels = []

for audio_file in audio_files_crema_d:
  file_name = audio_file.split('/')[3]
  segments = file_name.split('_')
  speakers.append(int(segments[0]))
  labels.append(segments[2])

print(speakers)
print(labels)
# Out:
# [1070, 1086, 1047, 1024, 1013, 1018, 1033, 1087, 1090, 1026, 1048, 1020, 1070, 1080, 1074, 1011, 1048, 1033, 1005, 1089, 1060, 1005, 1004, 1023, 1065, 1073, 1090, 1080, 1035, 1019, 1012, 1060, 1043, 1005, 1081, 1081, 1063, 1055, 1033, 1091, 1032, 1016, 1067, 1061, 1034, 1008, 1071, 1017, 1029, 1076, 1083, 1039, 1063, 1078, 1077, 1069, 1021, 1081, 1085, 1061, 1002, 1054, 1055, 1055, 1057, 1085, 1022, 1068, 1036, 1078, 1050, 1089, 1054, 1078, 1018, 1087, 1078, 1006, 1075, 1026, 1007, 1084, 1048, 1005, 1043, 1065, 1037, 1018, 1021, 1032, 1062, 1080, 1091, 1029, 1024, 1076, 1030, 1076, 1077, 1013, 1011, 1068, 1048, 1019, 1069, 1022, 1014, 1069, 1079, 1011, 1041, 1006, 1027, 1076, 1003, 1082, 1080, 1025, 1060, 1033, 1073, 1056, 1053, 1051, 1047, 1064, 1064, 1013, 1082, 1025, 1058, 1065, 1041, 1019, 1046, 1028, 1033, 1009, 1055, 1046, 1071, 1079, 1009, 1058, 1064, 1052, 1023, 1002, 1039, 1015, 1088, 1020, 1074, 1071, 1053, 1089, 1085, 1090, 1057, 1079, 1011, 1006, 1084, 1063, 1075, 1047, 1058, 1038, 1052, 1052, 1043, 1012, 1076, 1043, 1028, 1033, 1003, 1014, 1065, 1056, 1026, 1088, 1078, 1082, 1036, 1007, 1003, 1016, 1038, 1003, 1033, 1061, 1045, 1063, 1073, 1034, 1024, 1046, 1010, 1087, 1023, 1074, 1007, 1009, 1004, 1037, 1076, 1086, 1062, 1064, 1091, 1028, 1044, 1053, 1076, 1066, 1058, 1018, 1056, 1081, 1013, 1004, 1045, 1037, 1037, 1076, 1057, 1011, 1044, 1001, 1074, 1056, 1066, 1016, 1051, 1065, 1035, 1010, 1064, 1012, 1004, 1073, 1016, 1031, 1032, 1007, 1074, 1069, 1055, 1077, 1002, 1057, 1078, 1049, 1051, 1003, 1001, 1061, 1026, 1047, 1039, 1021, 1016, 1033, 1018, 1006, 
# ['SAD', 'ANG', 'DIS', 'HAP', 'NEU', 'DIS', 'DIS', 'HAP', 'FEA', 'HAP', 'DIS', 'NEU', 'SAD', 'FEA', 'FEA', 'DIS', 'HAP', 'ANG', 'NEU', 'NEU', 'HAP', 'HAP', 'ANG', 'ANG', 'NEU', 'FEA', 'SAD', 'HAP', 'ANG', 'FEA', 'FEA', 'FEA', 'HAP', 'SAD', 'ANG', 'NEU', 'DIS', 'ANG', 'ANG', 'SAD', 'NEU', 'HAP', 'ANG', 'HAP', 'SAD', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'HAP', 'ANG', 'ANG', 'NEU', 'ANG', 'SAD', 'FEA', 'ANG', 'SAD', 'DIS', 'FEA', 'SAD', 'ANG', 'NEU', 'SAD', 'FEA', 'DIS', 'HAP', 'ANG', 'HAP', 'ANG', 'FEA', 'DIS', 'HAP', 'HAP', 'NEU', 'NEU', 'ANG', 'SAD', 'DIS', 'NEU', 'HAP', 'DIS', 'DIS', 'ANG', 'SAD', 'HAP', 'FEA', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'FEA', 'ANG', 'HAP', 'DIS', 'DIS', 'FEA', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'FEA', 'NEU', 'ANG', 'FEA', 'NEU', 'FEA', 'HAP', 'FEA', 'FEA', 'HAP', 'ANG', 'SAD', 'ANG', 'ANG', 'SAD', 'SAD', 'DIS', 'SAD', 'NEU', 'ANG', 'ANG', 'DIS', 'FEA', 'DIS', 'ANG', 'ANG', 'DIS', 'NEU', 'FEA', 'FEA', 'ANG', 'HAP', 'ANG', 'DIS', 'ANG', 'DIS', 'DIS', 'SAD', 'FEA', 'SAD', 'HAP', 'ANG', 'FEA', 'DIS', 'ANG', 'HAP', 'NEU', 'FEA', 'DIS', 'ANG', 'FEA', 'HAP', 'HAP', 'HAP', 'HAP', 'NEU', 'DIS', 'NEU', 'NEU', 'FEA', 'HAP', 'SAD', 'FEA', 'DIS', 'SAD', 'NEU', 'NEU', 'DIS', 'HAP', 'NEU', 'SAD', 'NEU', 'ANG', 'DIS', 'HAP', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'SAD', 'FEA', 'NEU', 'NEU', 'ANG', 'HAP', 'HAP', 'NEU', 'DIS', 'DIS', 'DIS', 'FEA', 'FEA', 'SAD', 'NEU', 'HAP', 'DIS', 'SAD', 'NEU', 'FEA', 'SAD', 'DIS', 'ANG', 'ANG', 'ANG', 'SAD', 'HAP', 'HAP', 'FEA', 'DIS', 'FEA', 'ANG', 'HAP', 'DIS', 'FEA', 'ANG', 'HAP', 'FEA', 'NEU', 'NEU', 'DIS', 'SAD', 'NEU', 'FEA', 'FEA', 'SAD', 'DIS', 'SAD', 'ANG', 'DIS', 'FEA', 'SAD', 'SAD', 'DIS', 'HAP', 'SAD', 'NEU', 'HAP', 'FEA', 'HAP', 'NEU', 'HAP', 'ANG', 'SAD', 'SAD', 'DIS', 'DIS', 'HAP', 'ANG', 'FEA', 'FEA', 'NEU', 'HAP', 'SAD', 'HAP', 'FEA', 'SAD', 'SAD', 'FEA', 'HAP', 'SAD', 'SAD', 'NEU', 'SAD', 'SAD', 'ANG', 'DIS', 'SAD', 'HAP', 'NEU', 'ANG', 'ANG', 'NEU', 'DIS', 'ANG', 'FEA', 'ANG', 'SAD', 'SAD', 'DIS', 'FEA', 'SAD', 'HAP', 'SAD', 'NEU', 'DIS', 'ANG', 'DIS', 'NEU', 'DIS', 'SAD', 'HAP', 'FEA', 'SAD', 'SAD', 'ANG', 'DIS', 'FEA', 'FEA', 'HAP', 'NEU', 'SAD', 'DIS', 'NEU', 'NEU', 'FEA', 'DIS', 'FEA', 'HAP', 'FEA', 'FEA', 'NEU', 'DIS', 'NEU', 'NEU', 'ANG', 'HAP', 'FEA', 'HAP', 'DIS', 'SAD', 'FEA', 'ANG', 'HAP', 'HAP', 'SAD', 'SAD', 'ANG', 'FEA', 'ANG', 'FEA', 'DIS', 'HAP', 'DIS', 'HAP', 'DIS', 'ANG', 'ANG', 'FEA', 'DIS', 'FEA', 'SAD', 'ANG', 'ANG', 'NEU', 'ANG', 'HAP', 'SAD', 'ANG', 'HAP', 'HAP', 'DIS', 'HAP', 'HAP', 'FEA', 'FEA', 'DIS', 'FEA', 'FEA', 'DIS', 'DIS', 'ANG', 'DIS', 'ANG', 'ANG', 'ANG', 'NEU', 'ANG', 'HAP', 'SAD', 'HAP', 'DIS', 'SAD', 'SAD', 'FEA', 'HAP', 'HAP', 'NEU', 'SAD', 'NEU', 'FEA', 'SAD', 'HAP', 'ANG', 'DIS', 'HAP', 'ANG', 'HAP', 'NEU', 'NEU', 'ANG', 'NEU', 'NEU', 'DIS', 'NEU', 'DIS', 'ANG', 'FEA', 'SAD', 'NEU', 'DIS', 'FEA', 'FEA', 'SAD', 'ANG', 'ANG', 'ANG', 'SAD', 'ANG', 'ANG', 'DIS', 'HAP', 'DIS', 'SAD', 'FEA', 'ANG', 'DIS', 'NEU', 'NEU', 'ANG', 'DIS', 'FEA', 'ANG', 'NEU', 'HAP', 'DIS', 'NEU', 'SAD', 'FEA', 'ANG', 'ANG', 'ANG', 'NEU', 'ANG', 'SAD', 'DIS', 'FEA', 'ANG', 'NEU', 'FEA', 'HAP', 'ANG', 'SAD', 'FEA', 'ANG', 'NEU', 'ANG', 'FEA', 'ANG', 'ANG', 'ANG', 'ANG', 'DIS', 'DIS', 'NEU', 'ANG', 'FEA', 'HAP', 'ANG', 'FEA', 'NEU', 'ANG', 'DIS', 'SAD', 'DIS', 'HAP', 'SAD', 'NEU', 'ANG', 'DIS', 'DIS', 'NEU', 'FEA', 'NEU', 'HAP', 'FEA', 'FEA', 'HAP', 'SAD', 'DIS', 'ANG', 'ANG', 'NEU', 'FEA', 'SAD', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'NEU', 'HAP', 'DIS', 'FEA', 'SAD', 'DIS', 'NEU', 'ANG', 'HAP', 'NEU', 'DIS', 'DIS', 'DIS', 'ANG', 'SAD', 'SAD', 'NEU', 'HAP', 'DIS', 'SAD', 'ANG', 'DIS', 'ANG', 'FEA', 'HAP', 'NEU', 'DIS', 'SAD', 'DIS', 'ANG', 'SAD', 'ANG', 'NEU', 'SAD', 'NEU', 'FEA', 'NEU', 'ANG', 'FEA', 'DIS', 'FEA', 'FEA', 'FEA', 'ANG', 'NEU', 'ANG', 'NEU', 'NEU', 'DIS', 'FEA', 'HAP', 'NEU', 'NEU', 'NEU', 'ANG', 'DIS', 'FEA', 'DIS', 'ANG', 'FEA', 'FEA', 'NEU', 'HAP', 'ANG', 'ANG', 'FEA', 'NEU', 'ANG', 'FEA', 'DIS', 'HAP', 'DIS', 'NEU', 'HAP', 'NEU', 'SAD', 'FEA', 'F ...

# %% [markdown]
# ## Speaker normalisation

# %%
def speaker_normalisation(embeddings_array, speakers):
  '''
  Normalises embeddings_array for each speaker
  
  Parameters
  ------------
  embeddings_array: torch tensor
      The tensor of embeddings, one row for each audio file
  speakers: list of integers
      The list of speakers

  Returns
  ------------
  embeddings_array: torch tensor
      The tensor containg normalised embeddings 
      
  '''
  speaker_ids = set(speakers)
  for speaker_id in speaker_ids:
    speaker_embeddings_indices = np.where(np.array(speakers)==speaker_id)[0]
    speaker_embeddings = embeddings_array[speaker_embeddings_indices,:]
    normalised_speaker_embeddings = scaler.fit_transform(speaker_embeddings)
    embeddings_array[speaker_embeddings_indices] = torch.tensor(normalised_speaker_embeddings).float()
  return embeddings_array

# %% [markdown]
# ## Example 1: wav2vec 2.0

# %%
# normalised_embeddings_wav2vec = speaker_normalisation(embeddings_array_wav2vec, speakers)
 
# print('The shape of the normalised embeddings array is: {}'.format(normalised_embeddings_wav2vec.shape))
# print('Normalised Embeddings Array:')
# print((normalised_embeddings_wav2vec))
# print()
# columnwise_mean = torch.mean(speaker_normalisation(embeddings_array_wav2vec, speakers), 0)
# print('Columnwise_mean:')
# print(columnwise_mean)
# if torch.all(columnwise_mean < 10**(-6)):
#   print('All means are less than 10**-6')
# else:
#   print('All means are NOT less than 10**-6')

# %% [markdown]
# ## Example 2: Hubert

# %%
# normalised_embeddings_hubert = speaker_normalisation(embeddings_array_hubert, speakers)
 
# print('The shape of the normalised embeddings array is: {}'.format(normalised_embeddings_hubert.shape))
# print('Normalised Embeddings Array:')
# print((normalised_embeddings_hubert))
# print()
# columnwise_mean = torch.mean(speaker_normalisation(embeddings_array_hubert, speakers), 0)
# print('Columnwise_mean:')
# print(columnwise_mean)
# if torch.all(columnwise_mean < 10**(-6)):
#   print('All means are less than 10**-6')
# else:
#   print('All means are NOT less than 10**-6')

# %% [markdown]
# ## Example 3: Hybrid BYOLS

# %%
normalised_embeddings_byols = speaker_normalisation(embeddings_array_byols, speakers)
 
print('The shape of the normalised embeddings array is: {}'.format(normalised_embeddings_byols.shape))
print('Normalised Embeddings Array:')
print((normalised_embeddings_byols))
print()
columnwise_mean = torch.mean(speaker_normalisation(embeddings_array_byols, speakers), 0)
print('Columnwise_mean:')
print(columnwise_mean)
if torch.all(columnwise_mean < 10**(-6)):
  print('All means are less than 10**-6')
else:
  print('All means are NOT less than 10**-6')
# Out:
# The shape of the normalised embeddings array is: torch.Size([7442, 2048])
# Normalised Embeddings Array:
# tensor([[ 0.7446, -0.5880,  0.9038,  ..., -0.7028,  0.6437, -0.9952],
#         [ 0.3341,  0.5120,  0.2099,  ...,  2.2052,  0.3882,  2.4736],
#         [-1.4732, -0.4100, -0.2244,  ..., -0.4470, -0.5203, -0.7952],
#         ...,
#         [ 1.2575,  0.5924,  0.2838,  ..., -0.6039, -0.3173, -0.3609],
#         [ 1.7047,  0.5935,  1.0780,  ..., -0.8513,  1.5532, -0.3280],
#         [-1.1692, -1.5588, -0.0137,  ..., -0.1902,  0.2838,  0.7877]])
#
# Columnwise_mean:
# tensor([ 2.5630e-10,  6.4074e-10,  1.0252e-09,  ...,  2.0504e-09,
#         -5.7666e-10,  2.0504e-09])
# All means are less than 10**-6

# %% [markdown]
# ## Example 4: openSMILE compare

# %%
normalised_embeddings_compare = speaker_normalisation(embeddings_array_compare, speakers)
 
print('The shape of the normalised embeddings array is: {}'.format(normalised_embeddings_compare.shape))
print('Normalised Embeddings Array:')
print((normalised_embeddings_compare))
print()
columnwise_mean = torch.mean(speaker_normalisation(embeddings_array_compare, speakers), 0)
print('Columnwise_mean:')
print(columnwise_mean)
if torch.all(columnwise_mean < 10**(-6)):
  print('All means are less than 10**-6')
else:
  print('All means are NOT less than 10**-6')
# Out:
# The shape of the normalised embeddings array is: torch.Size([7442, 6373])
# Normalised Embeddings Array:
# tensor([[-0.4050, -0.0596, -0.8373,  ...,  0.1758,  1.2240,  0.7034],
#         [ 2.7049,  0.3318, -1.0071,  ...,  1.6309,  1.4679,  1.3748],
#         [-0.6486, -0.7046, -0.9542,  ..., -1.3291, -1.0214, -0.5734],
#         ...,
#         [ 0.3511, -0.1359, -0.1063,  ..., -1.3793, -0.3577,  3.2220],
#         [ 0.2447,  1.3583, -0.4678,  ..., -0.3359,  0.2238, -0.4654],
#         [-0.1443, -0.3259, -0.5513,  ...,  0.1735,  0.8594, -0.3413]])
#
# Columnwise_mean:
# tensor([ 3.0755e-09,  1.5378e-09, -7.6889e-10,  ..., -1.2815e-10,
#          0.0000e+00, -1.0252e-09])
# All means are less than 10**-6

# %% [markdown]
# ## Example 5: openSMILE egemaps

# %%
normalised_embeddings_egemaps = speaker_normalisation(embeddings_array_egemaps, speakers)
 
print('The shape of the normalised embeddings array is: {}'.format(normalised_embeddings_egemaps.shape))
print('Normalised Embeddings Array:')
print((normalised_embeddings_egemaps))
print()
columnwise_mean = torch.mean(speaker_normalisation(embeddings_array_egemaps, speakers), 0)
print('Columnwise_mean:')
print(columnwise_mean)
if torch.all(columnwise_mean < 10**(-6)):
  print('All means are less than 10**-6')
else:
  print('All means are NOT less than 10**-6')
# Out:
# The shape of the normalised embeddings array is: torch.Size([7442, 88])
# Normalised Embeddings Array:
# tensor([[-0.6591,  2.0093, -1.4414,  ...,  0.3270,  0.5491, -0.4299],
#         [ 0.2242,  0.1654,  0.4036,  ..., -0.4577, -0.5073,  1.4695],
#         [-1.0651, -0.9953, -0.8824,  ...,  2.2602,  0.3693, -0.7927],
#         ...,
#         [ 1.1003, -0.9123,  1.2628,  ...,  0.6397, -1.6709,  0.8557],
#         [ 0.8310,  0.9314,  0.3174,  ..., -0.2864,  0.1737,  0.9185],
#         [-0.7987, -0.2932, -0.8332,  ..., -0.3181, -0.0755, -0.5659]])
#
# Columnwise_mean:
# tensor([-1.0252e-09,  2.5630e-09,  1.0252e-09, -4.1007e-09,  2.0504e-09,
#         -1.0252e-09, -1.5378e-09,  6.7277e-10,  0.0000e+00,  1.5378e-09,
#          2.0504e-09, -4.1007e-09, -3.9726e-09, -2.0504e-09,  0.0000e+00,
#         -3.0755e-09,  0.0000e+00, -1.0252e-09,  1.0252e-09,  0.0000e+00,
#          1.0252e-09,  5.1259e-10,  1.0252e-09, -5.1259e-10, -1.0252e-09,
#         -1.5378e-09,  1.0252e-09, -1.5378e-09, -1.0252e-09, -3.0755e-09,
#         -1.6018e-09, -1.9222e-10,  6.4074e-10,  1.0252e-09,  1.0252e-09,
#          7.6889e-10,  5.1259e-10,  5.1259e-10,  1.5378e-09,  2.0504e-09,
#          1.0252e-09,  2.3067e-09,  2.5630e-10,  0.0000e+00,  0.0000e+00,
#         -2.0504e-09, -1.0252e-09,  1.2815e-09, -1.0252e-09, -2.5630e-09,
#          1.0252e-09,  2.0504e-09,  2.0504e-09,  2.5630e-10,  1.7941e-09,
#          2.0504e-09,  0.0000e+00,  1.0252e-09, -1.5378e-09,  1.5378e-09,
#          0.0000e+00,  1.0252e-09,  0.0000e+00,  0.0000e+00,  3.0755e-09,
#          1.2815e-09, -1.5378e-09, -5.1259e-10,  3.5881e-09,  1.0252e-09,
#         -7.6889e-10,  7.0481e-10,  1.5378e-09,  0.0000e+00,  5.1259e-10,
#          5.1259e-10,  2.0023e-09, -3.8444e-10,  2.5630e-10, -1.0252e-09,
#          2.5630e-10, -2.5630e-09,  2.8192e-09, -5.1259e-10,  4.4852e-09,
#          2.0504e-09, -1.0252e-09, -1.7941e-09])
# All means are less than 10**-6

# %% [markdown]
# ## Dividing into Training and Test sets

# %%
# Dividing into Training and Test sets
def split_train_test(normalised_embeddings_array, labels, test_size = 0.30):
  X_train, X_test, y_train, y_test = train_test_split(normalised_embeddings_array, labels, test_size=test_size, random_state=1)
  return X_train, X_test, y_train, y_test

# %%
# Train Test splitting
# X_train_wav2vec, X_test_wav2vec, y_train_wav2vec, y_test_wav2vec = split_train_test(normalised_embeddings_wav2vec, labels, test_size = 0.30)
# X_train_hubert, X_test_hubert, y_train_hubert, y_test_hubert = split_train_test(normalised_embeddings_hubert, labels, test_size = 0.30)
X_train_byols, X_test_byols, y_train_byols, y_test_byols = split_train_test(normalised_embeddings_byols, labels, test_size = 0.30)
X_train_compare, X_test_compare, y_train_compare, y_test_compare = split_train_test(normalised_embeddings_compare, labels, test_size = 0.30)
X_train_egemaps, X_test_egemaps, y_train_egemaps, y_test_egemaps = split_train_test(normalised_embeddings_egemaps, labels, test_size = 0.30)

models = ['byols', 'compare', 'egemaps']
normalised_embeddings_arrays = [normalised_embeddings_byols, normalised_embeddings_compare, normalised_embeddings_egemaps]

# Verify
for i in range(len(models)):
  print()
  print()
  print('MODEL: {}'.format(models[i]))
  print()
  X_train, X_test, y_train, y_test = split_train_test(normalised_embeddings_arrays[i], labels, test_size = 0.30)
  print('The shape of X_train is: {}'.format(X_train.shape))
  print('X_train')
  print(X_train)
  print()
  print('The shape of X_test is: {}'.format(X_test.shape))
  print('X_test')
  print(X_test)
  print()
  print('The length of y_train is: {}'.format(len(y_train)))
  print('y_train')
  print(y_train)
  print()
  print('The length of y_test is: {}'.format(len(y_test)))
  print('y_test')
  print(y_test)
# Out:
# MODEL: byols
#
# The shape of X_train is: torch.Size([5209, 2048])
# X_train
# tensor([[-0.7098,  0.1866, -0.4347,  ..., -0.5939,  1.7977,  0.2677],
#         [-1.4140, -0.1380,  0.6529,  ..., -2.0226, -1.1296, -0.5417],
#         [ 1.5970,  0.6306, -0.8873,  ..., -1.5388, -0.9297, -0.0992],
#         ...,
#         [-1.9555, -0.5569,  0.5279,  ...,  0.0810,  0.5017, -1.7509],
#         [ 0.5073,  0.7398, -1.9712,  ..., -0.7826, -0.4282, -0.9772],
#         [ 0.0717,  0.4705,  1.4781,  ...,  0.9536,  0.9126,  0.1855]])
#
# The shape of X_test is: torch.Size([2233, 2048])
# X_test
# tensor([[-1.4345,  1.7667,  0.2888,  ...,  0.5796, -0.4333, -0.2417],
#         [-0.8196, -0.8285,  0.7556,  ..., -0.8025, -1.5675, -0.9801],
#         [-1.1978, -1.0728, -0.1663,  ..., -0.0934, -0.0636, -1.4311],
#         ...,
#         [-0.6771, -0.2425,  0.9134,  ...,  0.7599, -1.0981,  2.0553],
#         [ 0.7506,  0.7905,  2.0447,  ..., -0.3995,  0.1458,  1.6060],
#         [-0.6730,  0.0987,  1.1640,  ...,  0.0543,  0.6453,  0.8884]])
#
# The length of y_train is: 5209
# y_train
# ['NEU', 'SAD', 'SAD', 'HAP', 'NEU', 'SAD', 'DIS', 'ANG', 'ANG', 'ANG', 'FEA', 'NEU', 'DIS', 'DIS', 'DIS', 'DIS', 'HAP', 'ANG', 'DIS', 'FEA', 'FEA', 'SAD', 'SAD', 'HAP', 'SAD', 'NEU', 'SAD', 'DIS', 'DIS', 'ANG', 'NEU', 'ANG', 'NEU', 'FEA', 'DIS', 'FEA', 'DIS', 'SAD', 'ANG', 'DIS', 'FEA', 'HAP', 'ANG', 'NEU', 'NEU', 'HAP', 'SAD', 'SAD', 'FEA', 'DIS', 'FEA', 'SAD', 'DIS', 'SAD', 'SAD', 'ANG', 'FEA', 'NEU', 'ANG', 'SAD', 'FEA', 'DIS', 'NEU', 'DIS', 'FEA', 'DIS', 'HAP', 'ANG', 'DIS', 'SAD', 'FEA', 'HAP', 'ANG', 'NEU', 'NEU', 'DIS', 'NEU', 'HAP', 'HAP', 'ANG', 'DIS', 'HAP', 'NEU', 'ANG', 'DIS', 'SAD', 'HAP', 'HAP', 'FEA', 'SAD', 'ANG', 'DIS', 'HAP', 'FEA', 'ANG', 'SAD', 'DIS', 'NEU', 'NEU', 'NEU', 'FEA', 'FEA', 'DIS', 'DIS', 'ANG', 'ANG', 'DIS', 'FEA', 'HAP', 'SAD', 'ANG', 'NEU', 'HAP', 'SAD', 'FEA', 'DIS', 'FEA', 'ANG', 'SAD', 'DIS', 'SAD', 'FEA', 'NEU', 'NEU', 'NEU', 'SAD', 'FEA', 'ANG', 'DIS', 'SAD', 'FEA', 'DIS', 'SAD', 'NEU', 'FEA', 'ANG', 'DIS', 'SAD', 'NEU', 'ANG', 'DIS', 'NEU', 'ANG', 'DIS', 'HAP', 'HAP', 'DIS', 'ANG', 'NEU', 'HAP', 'NEU', 'NEU', 'NEU', 'FEA', 'NEU', 'ANG', 'NEU', 'SAD', 'HAP', 'FEA', 'SAD', 'ANG', 'HAP', 'ANG', 'FEA', 'HAP', 'FEA', 'FEA', 'FEA', 'HAP', 'DIS', 'NEU', 'FEA', 'DIS', 'NEU', 'ANG', 'SAD', 'SAD', 'ANG', 'HAP', 'ANG', 'ANG', 'NEU', 'FEA', 'FEA', 'FEA', 'DIS', 'HAP', 'HAP', 'NEU', 'NEU', 'NEU', 'FEA', 'SAD', 'SAD', 'DIS', 'SAD', 'HAP', 'SAD', 'HAP', 'HAP', 'SAD', 'NEU', 'HAP', 'ANG', 'ANG', 'DIS', 'ANG', 'NEU', 'SAD', 'SAD', 'ANG', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'ANG', 'NEU', 'FEA', 'NEU', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'FEA', 'ANG', 'ANG', 'FEA', 'SAD', 'FEA', 'DIS', 'FEA', 'DIS', 'FEA', 'NEU', 'NEU', 'HAP', 'SAD', 'DIS', 'DIS', 'FEA', 'ANG', 'ANG', 'FEA', 'ANG', 'ANG', 'NEU', 'ANG', 'DIS', 'NEU', 'SAD', 'DIS', 'DIS', 'NEU', 'DIS', 'DIS', 'NEU', 'FEA', 'ANG', 'HAP', 'FEA', 'DIS', 'HAP', 'SAD', 'DIS', 'NEU', 'FEA', 'HAP', 'ANG', 'ANG', 'DIS', 'FEA', 'NEU', 'ANG', 'FEA', 'SAD', 'FEA', 'HAP', 'NEU', 'DIS', 'DIS', 'ANG', 'NEU', 'HAP', 'ANG', 'SAD', 'HAP', 'DIS', 'FEA', 'HAP', 'NEU', 'DIS', 'SAD', 'SAD', 'NEU', 'SAD', 'FEA', 'SAD', 'HAP', 'DIS', 'FEA', 'FEA', 'ANG', 'SAD', 'FEA', 'SAD', 'HAP', 'FEA', 'NEU', 'HAP', 'HAP', 'NEU', 'ANG', 'ANG', 'FEA', 'HAP', 'HAP', 'ANG', 'HAP', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'HAP', 'SAD', 'NEU', 'DIS', 'DIS', 'ANG', 'ANG', 'SAD', 'FEA', 'ANG', 'DIS', 'HAP', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'FEA', 'ANG', 'DIS', 'ANG', 'HAP', 'HAP', 'NEU', 'HAP', 'SAD', 'NEU', 'ANG', 'FEA', 'DIS', 'HAP', 'DIS', 'SAD', 'SAD', 'HAP', 'HAP', 'NEU', 'ANG', 'HAP', 'HAP', 'FEA', 'DIS', 'DIS', 'ANG', 'ANG', 'HAP', 'ANG', 'ANG', 'FEA', 'SAD', 'FEA', 'ANG', 'NEU', 'HAP', 'FEA', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'HAP', 'NEU', 'DIS', 'HAP', 'FEA', 'ANG', 'DIS', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'HAP', 'HAP', 'ANG', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'DIS', 'NEU', 'DIS', 'ANG', 'SAD', 'SAD', 'FEA', 'SAD', 'SAD', 'SAD', 'ANG', 'SAD', 'HAP', 'NEU', 'FEA', 'FEA', 'HAP', 'DIS', 'DIS', 'HAP', 'DIS', 'ANG', 'DIS', 'ANG', 'FEA', 'HAP', 'FEA', 'FEA', 'NEU', 'DIS', 'DIS', 'ANG', 'FEA', 'DIS', 'ANG', 'DIS', 'ANG', 'NEU', 'HAP', 'FEA', 'FEA', 'NEU', 'HAP', 'SAD', 'FEA', 'FEA', 'SAD', 'SAD', 'ANG', 'HAP', 'SAD', 'HAP', 'HAP', 'ANG', 'HAP', 'NEU', 'DIS', 'NEU', 'NEU', 'FEA', 'FEA', 'SAD', 'FEA', 'SAD', 'DIS', 'NEU', 'SAD', 'SAD', 'HAP', 'FEA', 'SAD', 'DIS', 'DIS', 'ANG', 'SAD', 'DIS', 'ANG', 'NEU', 'FEA', 'FEA', 'DIS', 'DIS', 'DIS', 'FEA', 'DIS', 'NEU', 'DIS', 'NEU', 'DIS', 'ANG', 'DIS', 'ANG', 'DIS', 'SAD', 'NEU', 'ANG', 'NEU', 'HAP', 'NEU', 'ANG', 'HAP', 'FEA', 'NEU', 'HAP', 'NEU', 'DIS', 'ANG', 'SAD', 'ANG', 'FEA', 'FEA', 'FEA', 'NEU', 'NEU', 'SAD', 'SAD', 'HAP', 'ANG', 'ANG', 'DIS', 'HAP', 'SAD', 'ANG', 'HAP', 'NEU', 'ANG', 'FEA', 'FEA', 'FEA', 'DIS', 'FEA', 'HAP', 'NEU', 'SAD', 'ANG', 'FEA', 'FEA', 'DIS', 'FEA', 'ANG', 'HAP', 'DIS', 'DIS', 'SAD', 'HAP', 'SAD', 'HAP', 'FEA', 'ANG', 'HAP', 'HAP', 'FEA', 'HAP', 'SAD', 'DIS', 'SAD', 'HAP', 'SAD', 'NEU', 'HAP', 'HAP', 'SAD', 'FEA', 'A ...
#
# The length of y_test is: 2233
# y_test
# ['FEA', 'FEA', 'FEA', 'FEA', 'FEA', 'SAD', 'HAP', 'ANG', 'SAD', 'NEU', 'HAP', 'NEU', 'ANG', 'ANG', 'SAD', 'FEA', 'HAP', 'NEU', 'ANG', 'FEA', 'FEA', 'HAP', 'FEA', 'FEA', 'ANG', 'SAD', 'ANG', 'ANG', 'HAP', 'DIS', 'HAP', 'ANG', 'DIS', 'FEA', 'FEA', 'HAP', 'SAD', 'ANG', 'SAD', 'NEU', 'ANG', 'DIS', 'SAD', 'DIS', 'FEA', 'FEA', 'ANG', 'NEU', 'FEA', 'FEA', 'HAP', 'FEA', 'ANG', 'HAP', 'FEA', 'DIS', 'HAP', 'HAP', 'HAP', 'FEA', 'DIS', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'SAD', 'DIS', 'ANG', 'FEA', 'FEA', 'SAD', 'NEU', 'SAD', 'SAD', 'DIS', 'SAD', 'DIS', 'HAP', 'NEU', 'HAP', 'NEU', 'DIS', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'FEA', 'FEA', 'NEU', 'ANG', 'HAP', 'ANG', 'ANG', 'HAP', 'DIS', 'NEU', 'ANG', 'HAP', 'HAP', 'FEA', 'FEA', 'ANG', 'FEA', 'ANG', 'SAD', 'DIS', 'DIS', 'SAD', 'FEA', 'DIS', 'DIS', 'FEA', 'NEU', 'DIS', 'FEA', 'SAD', 'FEA', 'HAP', 'HAP', 'ANG', 'DIS', 'HAP', 'DIS', 'ANG', 'DIS', 'SAD', 'DIS', 'DIS', 'DIS', 'HAP', 'DIS', 'SAD', 'SAD', 'FEA', 'DIS', 'FEA', 'DIS', 'DIS', 'FEA', 'DIS', 'ANG', 'ANG', 'ANG', 'FEA', 'SAD', 'SAD', 'FEA', 'DIS', 'ANG', 'SAD', 'ANG', 'HAP', 'FEA', 'SAD', 'HAP', 'SAD', 'ANG', 'NEU', 'NEU', 'FEA', 'NEU', 'FEA', 'NEU', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'HAP', 'DIS', 'NEU', 'DIS', 'ANG', 'HAP', 'FEA', 'NEU', 'DIS', 'FEA', 'ANG', 'FEA', 'ANG', 'ANG', 'ANG', 'DIS', 'FEA', 'SAD', 'FEA', 'HAP', 'HAP', 'NEU', 'NEU', 'NEU', 'SAD', 'NEU', 'HAP', 'ANG', 'FEA', 'FEA', 'HAP', 'ANG', 'FEA', 'SAD', 'NEU', 'SAD', 'HAP', 'ANG', 'HAP', 'DIS', 'FEA', 'NEU', 'HAP', 'FEA', 'FEA', 'NEU', 'FEA', 'NEU', 'HAP', 'ANG', 'FEA', 'NEU', 'NEU', 'NEU', 'SAD', 'DIS', 'SAD', 'DIS', 'FEA', 'DIS', 'FEA', 'DIS', 'FEA', 'ANG', 'ANG', 'DIS', 'SAD', 'ANG', 'HAP', 'SAD', 'DIS', 'HAP', 'HAP', 'ANG', 'FEA', 'NEU', 'SAD', 'FEA', 'NEU', 'HAP', 'HAP', 'SAD', 'FEA', 'NEU', 'HAP', 'HAP', 'DIS', 'HAP', 'FEA', 'DIS', 'HAP', 'SAD', 'SAD', 'FEA', 'HAP', 'ANG', 'HAP', 'NEU', 'ANG', 'DIS', 'ANG', 'SAD', 'SAD', 'HAP', 'HAP', 'HAP', 'FEA', 'HAP', 'HAP', 'NEU', 'DIS', 'SAD', 'NEU', 'FEA', 'SAD', 'HAP', 'FEA', 'SAD', 'HAP', 'ANG', 'DIS', 'HAP', 'SAD', 'DIS', 'DIS', 'SAD', 'NEU', 'DIS', 'HAP', 'ANG', 'ANG', 'DIS', 'HAP', 'ANG', 'DIS', 'HAP', 'NEU', 'DIS', 'FEA', 'DIS', 'HAP', 'SAD', 'FEA', 'ANG', 'FEA', 'SAD', 'HAP', 'SAD', 'DIS', 'NEU', 'NEU', 'HAP', 'NEU', 'DIS', 'ANG', 'DIS', 'SAD', 'SAD', 'ANG', 'DIS', 'HAP', 'SAD', 'DIS', 'NEU', 'SAD', 'SAD', 'DIS', 'DIS', 'DIS', 'ANG', 'FEA', 'FEA', 'SAD', 'ANG', 'NEU', 'DIS', 'SAD', 'DIS', 'FEA', 'HAP', 'SAD', 'FEA', 'SAD', 'FEA', 'NEU', 'FEA', 'DIS', 'HAP', 'FEA', 'HAP', 'HAP', 'DIS', 'NEU', 'FEA', 'NEU', 'SAD', 'FEA', 'DIS', 'SAD', 'HAP', 'HAP', 'NEU', 'DIS', 'HAP', 'ANG', 'SAD', 'NEU', 'NEU', 'HAP', 'ANG', 'DIS', 'FEA', 'ANG', 'FEA', 'FEA', 'ANG', 'FEA', 'DIS', 'HAP', 'NEU', 'NEU', 'SAD', 'SAD', 'FEA', 'NEU', 'NEU', 'FEA', 'SAD', 'HAP', 'FEA', 'NEU', 'HAP', 'DIS', 'HAP', 'ANG', 'SAD', 'ANG', 'HAP', 'SAD', 'FEA', 'SAD', 'FEA', 'DIS', 'NEU', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'SAD', 'SAD', 'SAD', 'SAD', 'HAP', 'SAD', 'DIS', 'SAD', 'DIS', 'NEU', 'SAD', 'ANG', 'DIS', 'SAD', 'SAD', 'ANG', 'NEU', 'SAD', 'ANG', 'NEU', 'HAP', 'ANG', 'FEA', 'FEA', 'SAD', 'HAP', 'DIS', 'SAD', 'NEU', 'FEA', 'NEU', 'SAD', 'HAP', 'SAD', 'SAD', 'HAP', 'DIS', 'FEA', 'HAP', 'NEU', 'HAP', 'FEA', 'ANG', 'FEA', 'SAD', 'SAD', 'NEU', 'ANG', 'ANG', 'SAD', 'FEA', 'SAD', 'DIS', 'SAD', 'SAD', 'ANG', 'FEA', 'SAD', 'SAD', 'NEU', 'ANG', 'NEU', 'DIS', 'FEA', 'SAD', 'DIS', 'FEA', 'DIS', 'DIS', 'SAD', 'FEA', 'ANG', 'HAP', 'HAP', 'HAP', 'HAP', 'SAD', 'ANG', 'SAD', 'SAD', 'HAP', 'ANG', 'DIS', 'SAD', 'DIS', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'ANG', 'DIS', 'DIS', 'FEA', 'FEA', 'FEA', 'FEA', 'NEU', 'DIS', 'DIS', 'SAD', 'ANG', 'SAD', 'SAD', 'ANG', 'DIS', 'HAP', 'HAP', 'ANG', 'NEU', 'NEU', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'DIS', 'DIS', 'NEU', 'ANG', 'SAD', 'SAD', 'HAP', 'SAD', 'SAD', 'FEA', 'NEU', 'NEU', 'SAD', 'HAP', 'DIS', 'DIS', 'NEU', 'DIS', 'SAD', 'SAD', 'DIS', 'HAP', 'ANG', 'SAD', 'DIS', 'HAP', 'SAD', 'ANG', 'DIS', 'SAD', 'SAD', 'NEU', 'DIS', 'HAP', 'FEA', 'NEU', 'S ...
#
#
# MODEL: compare
#
# The shape of X_train is: torch.Size([5209, 6373])
# X_train
# tensor([[ 0.1125, -0.1044, -1.6272,  ...,  0.0637, -1.1627, -1.3030],
#         [-0.9395, -0.9444, -0.8111,  ..., -0.0794,  0.1013, -0.3295],
#         [-0.7854,  1.0433,  1.4506,  ..., -0.5230,  0.1292, -1.0579],
#         ...,
#         [-0.7407,  0.0122, -0.1084,  ...,  0.6457, -0.3778,  0.5464],
#         [-0.7801, -0.0560, -0.9907,  ..., -1.7167, -0.4025, -0.7295],
#         [ 2.3647, -1.1051, -0.6043,  ...,  1.9637,  0.4465, -0.0416]])
#
# The shape of X_test is: torch.Size([2233, 6373])
# X_test
# tensor([[-0.4413, -0.5072, -0.8840,  ..., -1.4361, -1.6632, -0.5202],
#         [-1.3804, -1.8004,  1.1921,  ..., -0.1890, -1.0546, -0.9267],
#         [-0.4431, -0.2617,  1.4134,  ...,  0.2277,  0.3397,  1.4029],
#         ...,
#         [-0.3977,  1.0638, -0.7244,  ..., -0.4353,  0.1554, -0.4218],
#         [-0.7523,  0.5337, -0.2372,  ..., -1.2355, -0.1458, -1.1035],
#         [ 0.6151, -0.2380,  1.5309,  ...,  0.7937, -0.7914, -0.6972]])
#
# The length of y_train is: 5209
# y_train
# ['NEU', 'SAD', 'SAD', 'HAP', 'NEU', 'SAD', 'DIS', 'ANG', 'ANG', 'ANG', 'FEA', 'NEU', 'DIS', 'DIS', 'DIS', 'DIS', 'HAP', 'ANG', 'DIS', 'FEA', 'FEA', 'SAD', 'SAD', 'HAP', 'SAD', 'NEU', 'SAD', 'DIS', 'DIS', 'ANG', 'NEU', 'ANG', 'NEU', 'FEA', 'DIS', 'FEA', 'DIS', 'SAD', 'ANG', 'DIS', 'FEA', 'HAP', 'ANG', 'NEU', 'NEU', 'HAP', 'SAD', 'SAD', 'FEA', 'DIS', 'FEA', 'SAD', 'DIS', 'SAD', 'SAD', 'ANG', 'FEA', 'NEU', 'ANG', 'SAD', 'FEA', 'DIS', 'NEU', 'DIS', 'FEA', 'DIS', 'HAP', 'ANG', 'DIS', 'SAD', 'FEA', 'HAP', 'ANG', 'NEU', 'NEU', 'DIS', 'NEU', 'HAP', 'HAP', 'ANG', 'DIS', 'HAP', 'NEU', 'ANG', 'DIS', 'SAD', 'HAP', 'HAP', 'FEA', 'SAD', 'ANG', 'DIS', 'HAP', 'FEA', 'ANG', 'SAD', 'DIS', 'NEU', 'NEU', 'NEU', 'FEA', 'FEA', 'DIS', 'DIS', 'ANG', 'ANG', 'DIS', 'FEA', 'HAP', 'SAD', 'ANG', 'NEU', 'HAP', 'SAD', 'FEA', 'DIS', 'FEA', 'ANG', 'SAD', 'DIS', 'SAD', 'FEA', 'NEU', 'NEU', 'NEU', 'SAD', 'FEA', 'ANG', 'DIS', 'SAD', 'FEA', 'DIS', 'SAD', 'NEU', 'FEA', 'ANG', 'DIS', 'SAD', 'NEU', 'ANG', 'DIS', 'NEU', 'ANG', 'DIS', 'HAP', 'HAP', 'DIS', 'ANG', 'NEU', 'HAP', 'NEU', 'NEU', 'NEU', 'FEA', 'NEU', 'ANG', 'NEU', 'SAD', 'HAP', 'FEA', 'SAD', 'ANG', 'HAP', 'ANG', 'FEA', 'HAP', 'FEA', 'FEA', 'FEA', 'HAP', 'DIS', 'NEU', 'FEA', 'DIS', 'NEU', 'ANG', 'SAD', 'SAD', 'ANG', 'HAP', 'ANG', 'ANG', 'NEU', 'FEA', 'FEA', 'FEA', 'DIS', 'HAP', 'HAP', 'NEU', 'NEU', 'NEU', 'FEA', 'SAD', 'SAD', 'DIS', 'SAD', 'HAP', 'SAD', 'HAP', 'HAP', 'SAD', 'NEU', 'HAP', 'ANG', 'ANG', 'DIS', 'ANG', 'NEU', 'SAD', 'SAD', 'ANG', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'ANG', 'NEU', 'FEA', 'NEU', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'FEA', 'ANG', 'ANG', 'FEA', 'SAD', 'FEA', 'DIS', 'FEA', 'DIS', 'FEA', 'NEU', 'NEU', 'HAP', 'SAD', 'DIS', 'DIS', 'FEA', 'ANG', 'ANG', 'FEA', 'ANG', 'ANG', 'NEU', 'ANG', 'DIS', 'NEU', 'SAD', 'DIS', 'DIS', 'NEU', 'DIS', 'DIS', 'NEU', 'FEA', 'ANG', 'HAP', 'FEA', 'DIS', 'HAP', 'SAD', 'DIS', 'NEU', 'FEA', 'HAP', 'ANG', 'ANG', 'DIS', 'FEA', 'NEU', 'ANG', 'FEA', 'SAD', 'FEA', 'HAP', 'NEU', 'DIS', 'DIS', 'ANG', 'NEU', 'HAP', 'ANG', 'SAD', 'HAP', 'DIS', 'FEA', 'HAP', 'NEU', 'DIS', 'SAD', 'SAD', 'NEU', 'SAD', 'FEA', 'SAD', 'HAP', 'DIS', 'FEA', 'FEA', 'ANG', 'SAD', 'FEA', 'SAD', 'HAP', 'FEA', 'NEU', 'HAP', 'HAP', 'NEU', 'ANG', 'ANG', 'FEA', 'HAP', 'HAP', 'ANG', 'HAP', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'HAP', 'SAD', 'NEU', 'DIS', 'DIS', 'ANG', 'ANG', 'SAD', 'FEA', 'ANG', 'DIS', 'HAP', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'FEA', 'ANG', 'DIS', 'ANG', 'HAP', 'HAP', 'NEU', 'HAP', 'SAD', 'NEU', 'ANG', 'FEA', 'DIS', 'HAP', 'DIS', 'SAD', 'SAD', 'HAP', 'HAP', 'NEU', 'ANG', 'HAP', 'HAP', 'FEA', 'DIS', 'DIS', 'ANG', 'ANG', 'HAP', 'ANG', 'ANG', 'FEA', 'SAD', 'FEA', 'ANG', 'NEU', 'HAP', 'FEA', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'HAP', 'NEU', 'DIS', 'HAP', 'FEA', 'ANG', 'DIS', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'HAP', 'HAP', 'ANG', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'DIS', 'NEU', 'DIS', 'ANG', 'SAD', 'SAD', 'FEA', 'SAD', 'SAD', 'SAD', 'ANG', 'SAD', 'HAP', 'NEU', 'FEA', 'FEA', 'HAP', 'DIS', 'DIS', 'HAP', 'DIS', 'ANG', 'DIS', 'ANG', 'FEA', 'HAP', 'FEA', 'FEA', 'NEU', 'DIS', 'DIS', 'ANG', 'FEA', 'DIS', 'ANG', 'DIS', 'ANG', 'NEU', 'HAP', 'FEA', 'FEA', 'NEU', 'HAP', 'SAD', 'FEA', 'FEA', 'SAD', 'SAD', 'ANG', 'HAP', 'SAD', 'HAP', 'HAP', 'ANG', 'HAP', 'NEU', 'DIS', 'NEU', 'NEU', 'FEA', 'FEA', 'SAD', 'FEA', 'SAD', 'DIS', 'NEU', 'SAD', 'SAD', 'HAP', 'FEA', 'SAD', 'DIS', 'DIS', 'ANG', 'SAD', 'DIS', 'ANG', 'NEU', 'FEA', 'FEA', 'DIS', 'DIS', 'DIS', 'FEA', 'DIS', 'NEU', 'DIS', 'NEU', 'DIS', 'ANG', 'DIS', 'ANG', 'DIS', 'SAD', 'NEU', 'ANG', 'NEU', 'HAP', 'NEU', 'ANG', 'HAP', 'FEA', 'NEU', 'HAP', 'NEU', 'DIS', 'ANG', 'SAD', 'ANG', 'FEA', 'FEA', 'FEA', 'NEU', 'NEU', 'SAD', 'SAD', 'HAP', 'ANG', 'ANG', 'DIS', 'HAP', 'SAD', 'ANG', 'HAP', 'NEU', 'ANG', 'FEA', 'FEA', 'FEA', 'DIS', 'FEA', 'HAP', 'NEU', 'SAD', 'ANG', 'FEA', 'FEA', 'DIS', 'FEA', 'ANG', 'HAP', 'DIS', 'DIS', 'SAD', 'HAP', 'SAD', 'HAP', 'FEA', 'ANG', 'HAP', 'HAP', 'FEA', 'HAP', 'SAD', 'DIS', 'SAD', 'HAP', 'SAD', 'NEU', 'HAP', 'HAP', 'SAD', 'FEA', 'A ...
#
# The length of y_test is: 2233
# y_test
# ['FEA', 'FEA', 'FEA', 'FEA', 'FEA', 'SAD', 'HAP', 'ANG', 'SAD', 'NEU', 'HAP', 'NEU', 'ANG', 'ANG', 'SAD', 'FEA', 'HAP', 'NEU', 'ANG', 'FEA', 'FEA', 'HAP', 'FEA', 'FEA', 'ANG', 'SAD', 'ANG', 'ANG', 'HAP', 'DIS', 'HAP', 'ANG', 'DIS', 'FEA', 'FEA', 'HAP', 'SAD', 'ANG', 'SAD', 'NEU', 'ANG', 'DIS', 'SAD', 'DIS', 'FEA', 'FEA', 'ANG', 'NEU', 'FEA', 'FEA', 'HAP', 'FEA', 'ANG', 'HAP', 'FEA', 'DIS', 'HAP', 'HAP', 'HAP', 'FEA', 'DIS', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'SAD', 'DIS', 'ANG', 'FEA', 'FEA', 'SAD', 'NEU', 'SAD', 'SAD', 'DIS', 'SAD', 'DIS', 'HAP', 'NEU', 'HAP', 'NEU', 'DIS', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'FEA', 'FEA', 'NEU', 'ANG', 'HAP', 'ANG', 'ANG', 'HAP', 'DIS', 'NEU', 'ANG', 'HAP', 'HAP', 'FEA', 'FEA', 'ANG', 'FEA', 'ANG', 'SAD', 'DIS', 'DIS', 'SAD', 'FEA', 'DIS', 'DIS', 'FEA', 'NEU', 'DIS', 'FEA', 'SAD', 'FEA', 'HAP', 'HAP', 'ANG', 'DIS', 'HAP', 'DIS', 'ANG', 'DIS', 'SAD', 'DIS', 'DIS', 'DIS', 'HAP', 'DIS', 'SAD', 'SAD', 'FEA', 'DIS', 'FEA', 'DIS', 'DIS', 'FEA', 'DIS', 'ANG', 'ANG', 'ANG', 'FEA', 'SAD', 'SAD', 'FEA', 'DIS', 'ANG', 'SAD', 'ANG', 'HAP', 'FEA', 'SAD', 'HAP', 'SAD', 'ANG', 'NEU', 'NEU', 'FEA', 'NEU', 'FEA', 'NEU', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'HAP', 'DIS', 'NEU', 'DIS', 'ANG', 'HAP', 'FEA', 'NEU', 'DIS', 'FEA', 'ANG', 'FEA', 'ANG', 'ANG', 'ANG', 'DIS', 'FEA', 'SAD', 'FEA', 'HAP', 'HAP', 'NEU', 'NEU', 'NEU', 'SAD', 'NEU', 'HAP', 'ANG', 'FEA', 'FEA', 'HAP', 'ANG', 'FEA', 'SAD', 'NEU', 'SAD', 'HAP', 'ANG', 'HAP', 'DIS', 'FEA', 'NEU', 'HAP', 'FEA', 'FEA', 'NEU', 'FEA', 'NEU', 'HAP', 'ANG', 'FEA', 'NEU', 'NEU', 'NEU', 'SAD', 'DIS', 'SAD', 'DIS', 'FEA', 'DIS', 'FEA', 'DIS', 'FEA', 'ANG', 'ANG', 'DIS', 'SAD', 'ANG', 'HAP', 'SAD', 'DIS', 'HAP', 'HAP', 'ANG', 'FEA', 'NEU', 'SAD', 'FEA', 'NEU', 'HAP', 'HAP', 'SAD', 'FEA', 'NEU', 'HAP', 'HAP', 'DIS', 'HAP', 'FEA', 'DIS', 'HAP', 'SAD', 'SAD', 'FEA', 'HAP', 'ANG', 'HAP', 'NEU', 'ANG', 'DIS', 'ANG', 'SAD', 'SAD', 'HAP', 'HAP', 'HAP', 'FEA', 'HAP', 'HAP', 'NEU', 'DIS', 'SAD', 'NEU', 'FEA', 'SAD', 'HAP', 'FEA', 'SAD', 'HAP', 'ANG', 'DIS', 'HAP', 'SAD', 'DIS', 'DIS', 'SAD', 'NEU', 'DIS', 'HAP', 'ANG', 'ANG', 'DIS', 'HAP', 'ANG', 'DIS', 'HAP', 'NEU', 'DIS', 'FEA', 'DIS', 'HAP', 'SAD', 'FEA', 'ANG', 'FEA', 'SAD', 'HAP', 'SAD', 'DIS', 'NEU', 'NEU', 'HAP', 'NEU', 'DIS', 'ANG', 'DIS', 'SAD', 'SAD', 'ANG', 'DIS', 'HAP', 'SAD', 'DIS', 'NEU', 'SAD', 'SAD', 'DIS', 'DIS', 'DIS', 'ANG', 'FEA', 'FEA', 'SAD', 'ANG', 'NEU', 'DIS', 'SAD', 'DIS', 'FEA', 'HAP', 'SAD', 'FEA', 'SAD', 'FEA', 'NEU', 'FEA', 'DIS', 'HAP', 'FEA', 'HAP', 'HAP', 'DIS', 'NEU', 'FEA', 'NEU', 'SAD', 'FEA', 'DIS', 'SAD', 'HAP', 'HAP', 'NEU', 'DIS', 'HAP', 'ANG', 'SAD', 'NEU', 'NEU', 'HAP', 'ANG', 'DIS', 'FEA', 'ANG', 'FEA', 'FEA', 'ANG', 'FEA', 'DIS', 'HAP', 'NEU', 'NEU', 'SAD', 'SAD', 'FEA', 'NEU', 'NEU', 'FEA', 'SAD', 'HAP', 'FEA', 'NEU', 'HAP', 'DIS', 'HAP', 'ANG', 'SAD', 'ANG', 'HAP', 'SAD', 'FEA', 'SAD', 'FEA', 'DIS', 'NEU', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'SAD', 'SAD', 'SAD', 'SAD', 'HAP', 'SAD', 'DIS', 'SAD', 'DIS', 'NEU', 'SAD', 'ANG', 'DIS', 'SAD', 'SAD', 'ANG', 'NEU', 'SAD', 'ANG', 'NEU', 'HAP', 'ANG', 'FEA', 'FEA', 'SAD', 'HAP', 'DIS', 'SAD', 'NEU', 'FEA', 'NEU', 'SAD', 'HAP', 'SAD', 'SAD', 'HAP', 'DIS', 'FEA', 'HAP', 'NEU', 'HAP', 'FEA', 'ANG', 'FEA', 'SAD', 'SAD', 'NEU', 'ANG', 'ANG', 'SAD', 'FEA', 'SAD', 'DIS', 'SAD', 'SAD', 'ANG', 'FEA', 'SAD', 'SAD', 'NEU', 'ANG', 'NEU', 'DIS', 'FEA', 'SAD', 'DIS', 'FEA', 'DIS', 'DIS', 'SAD', 'FEA', 'ANG', 'HAP', 'HAP', 'HAP', 'HAP', 'SAD', 'ANG', 'SAD', 'SAD', 'HAP', 'ANG', 'DIS', 'SAD', 'DIS', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'ANG', 'DIS', 'DIS', 'FEA', 'FEA', 'FEA', 'FEA', 'NEU', 'DIS', 'DIS', 'SAD', 'ANG', 'SAD', 'SAD', 'ANG', 'DIS', 'HAP', 'HAP', 'ANG', 'NEU', 'NEU', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'DIS', 'DIS', 'NEU', 'ANG', 'SAD', 'SAD', 'HAP', 'SAD', 'SAD', 'FEA', 'NEU', 'NEU', 'SAD', 'HAP', 'DIS', 'DIS', 'NEU', 'DIS', 'SAD', 'SAD', 'DIS', 'HAP', 'ANG', 'SAD', 'DIS', 'HAP', 'SAD', 'ANG', 'DIS', 'SAD', 'SAD', 'NEU', 'DIS', 'HAP', 'FEA', 'NEU', 'S ...
#
#
# MODEL: egemaps
#
# The shape of X_train is: torch.Size([5209, 88])
# X_train
# tensor([[-6.7244e-01, -9.2247e-01, -4.3852e-01,  ..., -4.0350e-02,
#          -1.5652e+00,  1.9079e-01],
#         [-4.3291e+00, -1.4287e+00, -4.3140e+00,  ...,  5.7729e+00,
#          -2.4711e+00, -1.4933e+00],
#         [ 3.1939e-02,  3.1476e-01,  2.3446e-01,  ..., -2.7011e-01,
#           4.3107e-01, -6.3768e-01],
#         ...,
#         [-6.0636e-01, -3.2303e-01, -6.9015e-01,  ..., -9.2191e-02,
#           6.0636e-02, -9.2954e-01],
#         [-5.0548e-01, -4.0525e-01, -4.3309e-01,  ...,  5.2555e-03,
#          -1.7218e-01, -9.3040e-01],
#         [ 1.1160e+00,  4.5505e-01,  1.1753e+00,  ..., -3.2368e-01,
#           6.8826e-01,  1.7192e+00]])
#
# The shape of X_test is: torch.Size([2233, 88])
# X_test
# tensor([[ 0.0754, -0.5680,  0.0779,  ...,  0.6666,  0.1040,  0.0116],
#         [-0.2056, -1.1239, -0.0768,  ..., -0.7482, -0.9146, -1.4388],
#         [-0.9461, -1.9149, -0.4566,  ...,  2.4787,  0.6654, -0.7532],
#         ...,
#         [ 0.3815, -1.2874,  0.4135,  ..., -1.0041, -0.6618, -0.1361],
#         [-0.6345,  0.0302, -0.4484,  ...,  0.1572,  0.5277, -0.4919],
#         [ 0.7825,  0.3314,  0.7673,  ..., -0.2181,  0.2249,  1.0189]])
#
# The length of y_train is: 5209
# y_train
# ['NEU', 'SAD', 'SAD', 'HAP', 'NEU', 'SAD', 'DIS', 'ANG', 'ANG', 'ANG', 'FEA', 'NEU', 'DIS', 'DIS', 'DIS', 'DIS', 'HAP', 'ANG', 'DIS', 'FEA', 'FEA', 'SAD', 'SAD', 'HAP', 'SAD', 'NEU', 'SAD', 'DIS', 'DIS', 'ANG', 'NEU', 'ANG', 'NEU', 'FEA', 'DIS', 'FEA', 'DIS', 'SAD', 'ANG', 'DIS', 'FEA', 'HAP', 'ANG', 'NEU', 'NEU', 'HAP', 'SAD', 'SAD', 'FEA', 'DIS', 'FEA', 'SAD', 'DIS', 'SAD', 'SAD', 'ANG', 'FEA', 'NEU', 'ANG', 'SAD', 'FEA', 'DIS', 'NEU', 'DIS', 'FEA', 'DIS', 'HAP', 'ANG', 'DIS', 'SAD', 'FEA', 'HAP', 'ANG', 'NEU', 'NEU', 'DIS', 'NEU', 'HAP', 'HAP', 'ANG', 'DIS', 'HAP', 'NEU', 'ANG', 'DIS', 'SAD', 'HAP', 'HAP', 'FEA', 'SAD', 'ANG', 'DIS', 'HAP', 'FEA', 'ANG', 'SAD', 'DIS', 'NEU', 'NEU', 'NEU', 'FEA', 'FEA', 'DIS', 'DIS', 'ANG', 'ANG', 'DIS', 'FEA', 'HAP', 'SAD', 'ANG', 'NEU', 'HAP', 'SAD', 'FEA', 'DIS', 'FEA', 'ANG', 'SAD', 'DIS', 'SAD', 'FEA', 'NEU', 'NEU', 'NEU', 'SAD', 'FEA', 'ANG', 'DIS', 'SAD', 'FEA', 'DIS', 'SAD', 'NEU', 'FEA', 'ANG', 'DIS', 'SAD', 'NEU', 'ANG', 'DIS', 'NEU', 'ANG', 'DIS', 'HAP', 'HAP', 'DIS', 'ANG', 'NEU', 'HAP', 'NEU', 'NEU', 'NEU', 'FEA', 'NEU', 'ANG', 'NEU', 'SAD', 'HAP', 'FEA', 'SAD', 'ANG', 'HAP', 'ANG', 'FEA', 'HAP', 'FEA', 'FEA', 'FEA', 'HAP', 'DIS', 'NEU', 'FEA', 'DIS', 'NEU', 'ANG', 'SAD', 'SAD', 'ANG', 'HAP', 'ANG', 'ANG', 'NEU', 'FEA', 'FEA', 'FEA', 'DIS', 'HAP', 'HAP', 'NEU', 'NEU', 'NEU', 'FEA', 'SAD', 'SAD', 'DIS', 'SAD', 'HAP', 'SAD', 'HAP', 'HAP', 'SAD', 'NEU', 'HAP', 'ANG', 'ANG', 'DIS', 'ANG', 'NEU', 'SAD', 'SAD', 'ANG', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'ANG', 'NEU', 'FEA', 'NEU', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'FEA', 'ANG', 'ANG', 'FEA', 'SAD', 'FEA', 'DIS', 'FEA', 'DIS', 'FEA', 'NEU', 'NEU', 'HAP', 'SAD', 'DIS', 'DIS', 'FEA', 'ANG', 'ANG', 'FEA', 'ANG', 'ANG', 'NEU', 'ANG', 'DIS', 'NEU', 'SAD', 'DIS', 'DIS', 'NEU', 'DIS', 'DIS', 'NEU', 'FEA', 'ANG', 'HAP', 'FEA', 'DIS', 'HAP', 'SAD', 'DIS', 'NEU', 'FEA', 'HAP', 'ANG', 'ANG', 'DIS', 'FEA', 'NEU', 'ANG', 'FEA', 'SAD', 'FEA', 'HAP', 'NEU', 'DIS', 'DIS', 'ANG', 'NEU', 'HAP', 'ANG', 'SAD', 'HAP', 'DIS', 'FEA', 'HAP', 'NEU', 'DIS', 'SAD', 'SAD', 'NEU', 'SAD', 'FEA', 'SAD', 'HAP', 'DIS', 'FEA', 'FEA', 'ANG', 'SAD', 'FEA', 'SAD', 'HAP', 'FEA', 'NEU', 'HAP', 'HAP', 'NEU', 'ANG', 'ANG', 'FEA', 'HAP', 'HAP', 'ANG', 'HAP', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'HAP', 'SAD', 'NEU', 'DIS', 'DIS', 'ANG', 'ANG', 'SAD', 'FEA', 'ANG', 'DIS', 'HAP', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'FEA', 'ANG', 'DIS', 'ANG', 'HAP', 'HAP', 'NEU', 'HAP', 'SAD', 'NEU', 'ANG', 'FEA', 'DIS', 'HAP', 'DIS', 'SAD', 'SAD', 'HAP', 'HAP', 'NEU', 'ANG', 'HAP', 'HAP', 'FEA', 'DIS', 'DIS', 'ANG', 'ANG', 'HAP', 'ANG', 'ANG', 'FEA', 'SAD', 'FEA', 'ANG', 'NEU', 'HAP', 'FEA', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'HAP', 'NEU', 'DIS', 'HAP', 'FEA', 'ANG', 'DIS', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'ANG', 'HAP', 'HAP', 'ANG', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'DIS', 'NEU', 'DIS', 'ANG', 'SAD', 'SAD', 'FEA', 'SAD', 'SAD', 'SAD', 'ANG', 'SAD', 'HAP', 'NEU', 'FEA', 'FEA', 'HAP', 'DIS', 'DIS', 'HAP', 'DIS', 'ANG', 'DIS', 'ANG', 'FEA', 'HAP', 'FEA', 'FEA', 'NEU', 'DIS', 'DIS', 'ANG', 'FEA', 'DIS', 'ANG', 'DIS', 'ANG', 'NEU', 'HAP', 'FEA', 'FEA', 'NEU', 'HAP', 'SAD', 'FEA', 'FEA', 'SAD', 'SAD', 'ANG', 'HAP', 'SAD', 'HAP', 'HAP', 'ANG', 'HAP', 'NEU', 'DIS', 'NEU', 'NEU', 'FEA', 'FEA', 'SAD', 'FEA', 'SAD', 'DIS', 'NEU', 'SAD', 'SAD', 'HAP', 'FEA', 'SAD', 'DIS', 'DIS', 'ANG', 'SAD', 'DIS', 'ANG', 'NEU', 'FEA', 'FEA', 'DIS', 'DIS', 'DIS', 'FEA', 'DIS', 'NEU', 'DIS', 'NEU', 'DIS', 'ANG', 'DIS', 'ANG', 'DIS', 'SAD', 'NEU', 'ANG', 'NEU', 'HAP', 'NEU', 'ANG', 'HAP', 'FEA', 'NEU', 'HAP', 'NEU', 'DIS', 'ANG', 'SAD', 'ANG', 'FEA', 'FEA', 'FEA', 'NEU', 'NEU', 'SAD', 'SAD', 'HAP', 'ANG', 'ANG', 'DIS', 'HAP', 'SAD', 'ANG', 'HAP', 'NEU', 'ANG', 'FEA', 'FEA', 'FEA', 'DIS', 'FEA', 'HAP', 'NEU', 'SAD', 'ANG', 'FEA', 'FEA', 'DIS', 'FEA', 'ANG', 'HAP', 'DIS', 'DIS', 'SAD', 'HAP', 'SAD', 'HAP', 'FEA', 'ANG', 'HAP', 'HAP', 'FEA', 'HAP', 'SAD', 'DIS', 'SAD', 'HAP', 'SAD', 'NEU', 'HAP', 'HAP', 'SAD', 'FEA', 'A ...
#
# The length of y_test is: 2233
# y_test
# ['FEA', 'FEA', 'FEA', 'FEA', 'FEA', 'SAD', 'HAP', 'ANG', 'SAD', 'NEU', 'HAP', 'NEU', 'ANG', 'ANG', 'SAD', 'FEA', 'HAP', 'NEU', 'ANG', 'FEA', 'FEA', 'HAP', 'FEA', 'FEA', 'ANG', 'SAD', 'ANG', 'ANG', 'HAP', 'DIS', 'HAP', 'ANG', 'DIS', 'FEA', 'FEA', 'HAP', 'SAD', 'ANG', 'SAD', 'NEU', 'ANG', 'DIS', 'SAD', 'DIS', 'FEA', 'FEA', 'ANG', 'NEU', 'FEA', 'FEA', 'HAP', 'FEA', 'ANG', 'HAP', 'FEA', 'DIS', 'HAP', 'HAP', 'HAP', 'FEA', 'DIS', 'SAD', 'NEU', 'DIS', 'DIS', 'FEA', 'SAD', 'DIS', 'ANG', 'FEA', 'FEA', 'SAD', 'NEU', 'SAD', 'SAD', 'DIS', 'SAD', 'DIS', 'HAP', 'NEU', 'HAP', 'NEU', 'DIS', 'SAD', 'FEA', 'FEA', 'HAP', 'NEU', 'FEA', 'FEA', 'NEU', 'ANG', 'HAP', 'ANG', 'ANG', 'HAP', 'DIS', 'NEU', 'ANG', 'HAP', 'HAP', 'FEA', 'FEA', 'ANG', 'FEA', 'ANG', 'SAD', 'DIS', 'DIS', 'SAD', 'FEA', 'DIS', 'DIS', 'FEA', 'NEU', 'DIS', 'FEA', 'SAD', 'FEA', 'HAP', 'HAP', 'ANG', 'DIS', 'HAP', 'DIS', 'ANG', 'DIS', 'SAD', 'DIS', 'DIS', 'DIS', 'HAP', 'DIS', 'SAD', 'SAD', 'FEA', 'DIS', 'FEA', 'DIS', 'DIS', 'FEA', 'DIS', 'ANG', 'ANG', 'ANG', 'FEA', 'SAD', 'SAD', 'FEA', 'DIS', 'ANG', 'SAD', 'ANG', 'HAP', 'FEA', 'SAD', 'HAP', 'SAD', 'ANG', 'NEU', 'NEU', 'FEA', 'NEU', 'FEA', 'NEU', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'HAP', 'DIS', 'NEU', 'DIS', 'ANG', 'HAP', 'FEA', 'NEU', 'DIS', 'FEA', 'ANG', 'FEA', 'ANG', 'ANG', 'ANG', 'DIS', 'FEA', 'SAD', 'FEA', 'HAP', 'HAP', 'NEU', 'NEU', 'NEU', 'SAD', 'NEU', 'HAP', 'ANG', 'FEA', 'FEA', 'HAP', 'ANG', 'FEA', 'SAD', 'NEU', 'SAD', 'HAP', 'ANG', 'HAP', 'DIS', 'FEA', 'NEU', 'HAP', 'FEA', 'FEA', 'NEU', 'FEA', 'NEU', 'HAP', 'ANG', 'FEA', 'NEU', 'NEU', 'NEU', 'SAD', 'DIS', 'SAD', 'DIS', 'FEA', 'DIS', 'FEA', 'DIS', 'FEA', 'ANG', 'ANG', 'DIS', 'SAD', 'ANG', 'HAP', 'SAD', 'DIS', 'HAP', 'HAP', 'ANG', 'FEA', 'NEU', 'SAD', 'FEA', 'NEU', 'HAP', 'HAP', 'SAD', 'FEA', 'NEU', 'HAP', 'HAP', 'DIS', 'HAP', 'FEA', 'DIS', 'HAP', 'SAD', 'SAD', 'FEA', 'HAP', 'ANG', 'HAP', 'NEU', 'ANG', 'DIS', 'ANG', 'SAD', 'SAD', 'HAP', 'HAP', 'HAP', 'FEA', 'HAP', 'HAP', 'NEU', 'DIS', 'SAD', 'NEU', 'FEA', 'SAD', 'HAP', 'FEA', 'SAD', 'HAP', 'ANG', 'DIS', 'HAP', 'SAD', 'DIS', 'DIS', 'SAD', 'NEU', 'DIS', 'HAP', 'ANG', 'ANG', 'DIS', 'HAP', 'ANG', 'DIS', 'HAP', 'NEU', 'DIS', 'FEA', 'DIS', 'HAP', 'SAD', 'FEA', 'ANG', 'FEA', 'SAD', 'HAP', 'SAD', 'DIS', 'NEU', 'NEU', 'HAP', 'NEU', 'DIS', 'ANG', 'DIS', 'SAD', 'SAD', 'ANG', 'DIS', 'HAP', 'SAD', 'DIS', 'NEU', 'SAD', 'SAD', 'DIS', 'DIS', 'DIS', 'ANG', 'FEA', 'FEA', 'SAD', 'ANG', 'NEU', 'DIS', 'SAD', 'DIS', 'FEA', 'HAP', 'SAD', 'FEA', 'SAD', 'FEA', 'NEU', 'FEA', 'DIS', 'HAP', 'FEA', 'HAP', 'HAP', 'DIS', 'NEU', 'FEA', 'NEU', 'SAD', 'FEA', 'DIS', 'SAD', 'HAP', 'HAP', 'NEU', 'DIS', 'HAP', 'ANG', 'SAD', 'NEU', 'NEU', 'HAP', 'ANG', 'DIS', 'FEA', 'ANG', 'FEA', 'FEA', 'ANG', 'FEA', 'DIS', 'HAP', 'NEU', 'NEU', 'SAD', 'SAD', 'FEA', 'NEU', 'NEU', 'FEA', 'SAD', 'HAP', 'FEA', 'NEU', 'HAP', 'DIS', 'HAP', 'ANG', 'SAD', 'ANG', 'HAP', 'SAD', 'FEA', 'SAD', 'FEA', 'DIS', 'NEU', 'SAD', 'ANG', 'SAD', 'FEA', 'SAD', 'SAD', 'SAD', 'SAD', 'SAD', 'HAP', 'SAD', 'DIS', 'SAD', 'DIS', 'NEU', 'SAD', 'ANG', 'DIS', 'SAD', 'SAD', 'ANG', 'NEU', 'SAD', 'ANG', 'NEU', 'HAP', 'ANG', 'FEA', 'FEA', 'SAD', 'HAP', 'DIS', 'SAD', 'NEU', 'FEA', 'NEU', 'SAD', 'HAP', 'SAD', 'SAD', 'HAP', 'DIS', 'FEA', 'HAP', 'NEU', 'HAP', 'FEA', 'ANG', 'FEA', 'SAD', 'SAD', 'NEU', 'ANG', 'ANG', 'SAD', 'FEA', 'SAD', 'DIS', 'SAD', 'SAD', 'ANG', 'FEA', 'SAD', 'SAD', 'NEU', 'ANG', 'NEU', 'DIS', 'FEA', 'SAD', 'DIS', 'FEA', 'DIS', 'DIS', 'SAD', 'FEA', 'ANG', 'HAP', 'HAP', 'HAP', 'HAP', 'SAD', 'ANG', 'SAD', 'SAD', 'HAP', 'ANG', 'DIS', 'SAD', 'DIS', 'HAP', 'NEU', 'SAD', 'HAP', 'HAP', 'ANG', 'DIS', 'DIS', 'FEA', 'FEA', 'FEA', 'FEA', 'NEU', 'DIS', 'DIS', 'SAD', 'ANG', 'SAD', 'SAD', 'ANG', 'DIS', 'HAP', 'HAP', 'ANG', 'NEU', 'NEU', 'FEA', 'FEA', 'SAD', 'SAD', 'SAD', 'DIS', 'DIS', 'NEU', 'ANG', 'SAD', 'SAD', 'HAP', 'SAD', 'SAD', 'FEA', 'NEU', 'NEU', 'SAD', 'HAP', 'DIS', 'DIS', 'NEU', 'DIS', 'SAD', 'SAD', 'DIS', 'HAP', 'ANG', 'SAD', 'DIS', 'HAP', 'SAD', 'ANG', 'DIS', 'SAD', 'SAD', 'NEU', 'DIS', 'HAP', 'FEA', 'NEU', 'S ...

# %% [markdown]
# # EmoDB

# %% [markdown]
# ## Phase 1

# %%
# Phase_1
# Load dataset
! kaggle datasets download -d piyushagni5/berlin-database-of-emotional-speech-emodb
! unzip berlin-database-of-emotional-speech-emodb.zip

# Resample dataset
audio_files_emo = glob(os.path.join('/content/wav','*.wav'))
audio_list_emo= load_audio_files(audio_files_emo, resampling_frequency=16000)


# Verify phase_1
print()
print('number of audio files: {}'.format(len(audio_list_emo)))
print(audio_list_emo[0].shape)
# Out:
# berlin-database-of-emotional-speech-emodb.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  berlin-database-of-emotional-speech-emodb.zip
# replace wav/03a01Fa.wav? [y]es, [n]o, [A]ll, [N]one, [r]ename: None
#
# number of audio files: 535
# torch.Size([87957])

# %% [markdown]
# ## Phase 2

# %%
# Phase_2
# Wav2vec
# model = audio_embeddings_model(model_name='wav2vec2')
# embeddings_array_wav2vec = audio_embeddings(audio_list_emo[:2], model_name='wav2vec2', model=model)

# Hubert
# model = audio_embeddings_model(model_name='hubert')
# embeddings_array_hubert = audio_embeddings(audio_list_emo[:2], model_name='hubert', model=model)

# Hybrid BYOLS
model = audio_embeddings_model(model_name='hybrid_byols')
embeddings_array_byols = audio_embeddings(audio_list_emo, model_name='hybrid_byols', model=model)

# EmoDB compare
model = audio_embeddings_model(model_name='compare')
embeddings_array_compare = audio_embeddings(audio_list_emo, model_name='compare', model=model)

# EmoDB egemaps
model = audio_embeddings_model(model_name='egemaps')
embeddings_array_egemaps = audio_embeddings(audio_list_emo, model_name='egemaps', model=model)


# Verify Phase_2
models = ['byols', 'compare', 'egemaps']
embeddings_arrays = [embeddings_array_byols, embeddings_array_compare, embeddings_array_egemaps]

for i in range(len(models)):
  print()
  print()
  print('MODEL: {}'.format(models[i]))
  print()
  print('The shape of the embeddings array is {}'.format(embeddings_arrays[i].shape))
  print('The embeddings array is: ')
  print((embeddings_arrays[i]))
# Out:
# Generating Embeddings...: 100%|██████████| 535/535 [00:24<00:00, 21.72it/s]
# 100%|██████████| 535/535 [00:55<00:00,  9.65it/s]
# 100%|██████████| 535/535 [01:00<00:00,  8.87it/s]
# MODEL: byols
#
# The shape of the embeddings array is torch.Size([535, 2048])
# The embeddings array is:
# tensor([[ 3.2043,  5.1246,  0.7757,  ...,  5.2862, -1.5630,  4.2663],
#         [ 3.6598,  7.1753,  2.1226,  ...,  4.0313,  0.7807,  3.5573],
#         [ 4.9119,  4.5869,  1.1540,  ...,  4.8820, -0.8673,  2.8869],
#         ...,
#         [ 5.5373,  3.1271,  1.8133,  ...,  4.4415, -1.1598,  3.0143],
#         [ 3.0584,  3.6032, -0.1855,  ...,  5.9404, -0.3081,  3.4181],
#         [ 4.2166,  3.6123,  1.7138,  ...,  4.7688,  0.1352,  3.7743]])
#
#
# MODEL: compare
#
# The shape of the embeddings array is torch.Size([535, 6373])
# The embeddings array is:
# tensor([[2.3726e+00, 1.0517e-01, 9.6310e-01,  ..., 6.7568e+01, 1.1536e+02,
#          5.9326e+01],
#         [2.2908e+00, 1.0602e-01, 9.7135e-01,  ..., 6.3124e+01, 1.3373e+02,
#          7.4071e+01],
#         [2.5637e+00, 1.5772e-01, 3.5570e-01,  ..., 6.2385e+01, 1.1408e+02,
#          5.0285e+01],
#         ...,
#         [3.4053e+00, 4.1453e-01, 3.4188e-02,  ..., 7.7860e+01, 1.4425e+02,
#          7.8650e+01],
#         [3.1053e+00, 8.5185e-01, 0.0000e+00,  ..., 6.6647e+01, 1.4844e+02,
#          6.5368e+01],
#         [2.3131e+00, 1.1364e-01, 3.3712e-01,  ..., 7.5067e+01, 9.4801e+01,
#          4.9728e+01]])
#
#
# MODEL: egemaps
#
# The shape of the embeddings array is torch.Size([535, 88])
# The embeddings array is:
# tensor([[ 2.5813e+01,  2.2789e-01,  1.9418e+01,  ...,  2.0000e-01,
#           2.9058e-01, -1.8923e+01],
#         [ 3.3254e+01,  8.2665e-02,  3.0914e+01,  ...,  8.9091e-02,
#           6.3023e-02, -1.3424e+01],
#         [ 3.2488e+01,  1.3802e-01,  2.9022e+01,  ...,  6.5455e-02,
#           4.6390e-02, -1.7756e+01],
#         ...,
#         [ 4.0426e+01,  1.3680e-01,  3.5975e+01,  ...,  5.2857e-02,
#           2.8643e-02, -2.4766e+01],
#         [ 2.9271e+01,  1.8650e-01,  2.6371e+01,  ...,  8.6923e-02,
#           6.8093e-02, -1.9044e+01],
#         [ 2.8687e+01,  1.4500e-01,  2.7104e+01,  ...,  1.0500e-01,
#           6.1033e-02, -1.7781e+01]])

# %% [markdown]
# ## Phase 3

# %%
# Phase_3
speakers = []
labels = []

for audio_file in audio_files_emo:
  file_name = audio_file.split('/')[3]
  speakers.append(int(file_name[:2]))
  labels.append(file_name[5:7])


# Verify speakers and labels array
print()
print()
print('Speakers:')
print(speakers)
print('Labels:')
print(labels)


# Normalised arrays
# normalised_embeddings_wav2vec = speaker_normalisation(embeddings_array_wav2vec, speakers)
# normalised_embeddings_hubert = speaker_normalisation(embeddings_array_hubert, speakers)
normalised_embeddings_byols = speaker_normalisation(embeddings_array_byols, speakers)
normalised_embeddings_compare= speaker_normalisation(embeddings_array_compare, speakers)
normalised_embeddings_egemaps = speaker_normalisation(embeddings_array_egemaps, speakers)


# Verifying Phase_3
normalised_embeddings_arrays = [normalised_embeddings_byols, normalised_embeddings_compare, normalised_embeddings_egemaps]

for i in range(len(models)):
  print()
  print()
  print('MODEL: {}'.format(models[i]))
  print()
  print('The shape of the normalised embeddings array is: {}'.format(normalised_embeddings_arrays[i].shape))
  print('Normalised Embeddings Array:')
  print((normalised_embeddings_arrays[i]))
  print()
  columnwise_mean = torch.mean(speaker_normalisation(embeddings_arrays[i], speakers), 0)
  print('Columnwise_mean:')
  print(columnwise_mean)
  if torch.all(columnwise_mean < 10**(-6)):
    print('All means are less than 10**-6')
  else:
    print('All means are NOT less than 10**-6')
# Out:
# Speakers:
# [14, 13, 14, 14, 10, 16, 3, 14, 16, 15, 9, 15, 14, 9, 8, 11, 14, 11, 8, 11, 3, 13, 8, 14, 14, 13, 14, 12, 10, 3, 8, 16, 3, 13, 14, 14, 12, 11, 16, 13, 3, 15, 15, 15, 14, 15, 14, 16, 8, 3, 8, 3, 11, 12, 15, 14, 14, 8, 14, 13, 16, 12, 14, 15, 12, 16, 10, 9, 14, 13, 15, 16, 13, 15, 10, 3, 8, 3, 11, 10, 15, 8, 11, 13, 8, 9, 11, 14, 13, 14, 16, 3, 16, 11, 11, 13, 14, 9, 13, 15, 8, 16, 15, 9, 14, 8, 14, 13, 13, 16, 15, 11, 3, 16, 13, 13, 14, 11, 13, 15, 16, 12, 3, 9, 14, 3, 14, 16, 13, 13, 15, 12, 10, 16, 9, 10, 14, 8, 16, 13, 15, 15, 3, 3, 14, 11, 10, 16, 14, 9, 9, 8, 16, 3, 11, 9, 14, 9, 14, 13, 14, 16, 14, 10, 9, 14, 11, 14, 13, 8, 15, 8, 15, 3, 15, 12, 8, 13, 13, 9, 3, 9, 8, 8, 14, 9, 3, 15, 11, 16, 16, 9, 8, 3, 16, 9, 15, 8, 8, 8, 12, 16, 15, 14, 3, 13, 14, 14, 16, 9, 13, 16, 13, 11, 12, 10, 10, 12, 9, 14, 13, 3, 3, 16, 13, 16, 3, 11, 10, 10, 13, 8, 10, 10, 11, 10, 16, 16, 16, 16, 12, 9, 14, 15, 16, 16, 16, 9, 13, 13, 12, 3, 10, 8, 15, 11, 11, 15, 16, 15, 13, 15, 3, 15, 15, 10, 12, 11, 15, 8, 11, 8, 3, 14, 14, 13, 9, 10, 12, 14, 16, 8, 13, 11, 15, 11, 3, 12, 9, 3, 16, 16, 12, 16, 13, 11, 16, 16, 15, 15, 12, 3, 15, 13, 11, 10, 14, 11, 12, 12, 8, 13, 10, 15, 3, 10, 13, 15, 9, 14, 14, 8, 14, 10, 15, 8, 16, 8, 14, 16, 8, 13, 15, 15, 11, 13, 3, 12, 12, 3, 11, 8, 14, 16, 8, 9, 9, 13, 12, 16, 8, 11, 10, 11, 8, 15, 16, 16, 16, 16, 3, 3, 16, 14, 14, 3, 10, 16, 12, 9, 9, 14, 16, 11, 15, 16, 16, 16, 8, 8, 14, 12, 8, 16, 13, 11, 3, 12, 14, 8, 16, 11, 11, 9, 16, 12, 10, 10, 15, 10, 13, 8, 9, 9, 14, 8, 14, 11, 10, 10, 3, 14, 3, 16, 9, 11, 14, 16, 11, 10, 16, 9, 15, 14, 16, 10, 8, 3, 8, 13, 13, 15, 11, 13, 13, 11, 15, 8, 16, 3, 15, 14, 13, 8, 12, 8, 8, 15, 13, 11, 13, 15, 8, 16, 11, 11, 10, 11, 9, 9, 15, 8, 8, 8, 10, 9, 10, 15, 15, 9, 16, 3, 13, 11, 14, 3, 14, 12, 8, 14, 12, 16, 11, 13, 13, 14, 13, 3, 9, 8, 9, 8, 15, 12, 8, 8, 11, 13, 3, 3, 12, 14, 11, 16, 11, 16, 13, 11, 13, 11, 15, 13, 9, 10, 11, 3, 3, 13, 15, 11, 16, 3, 12, 14, 9, 12, 14, 11, 10, 13, 10, 14, 16, 12, 9]
# Labels:
# ['Ta', 'Na', 'Lb', 'Na', 'Ta', 'Wb', 'Nc', 'Tc', 'Ta', 'Lc', 'Na', 'Fa', 'Fb', 'Nd', 'La', 'Wd', 'Ea', 'Nb', 'Nb', 'Ec', 'Na', 'Aa', 'Tb', 'Fb', 'Wb', 'Wa', 'Tb', 'Wc', 'La', 'Fc', 'Wd', 'Wb', 'La', 'Fc', 'Tb', 'Wd', 'Wc', 'Eb', 'Aa', 'Fa', 'Wc', 'Fb', 'Ac', 'Nc', 'Eb', 'Tc', 'Ld', 'Ea', 'Wa', 'Nd', 'Aa', 'Wb', 'Fd', 'Ac', 'Wb', 'Lb', 'Wb', 'Na', 'Lb', 'Td', 'Lb', 'Wb', 'Ac', 'La', 'Lb', 'Nc', 'Fd', 'Fa', 'Ta', 'Ad', 'Wa', 'Wc', 'Tc', 'Tc', 'Wb', 'Td', 'Fe', 'Nc', 'Ad', 'La', 'Lb', 'Na', 'Ad', 'Lb', 'Tc', 'Fa', 'Fc', 'Wc', 'Fd', 'Fc', 'Lb', 'Tb', 'Fd', 'Nc', 'Wc', 'Na', 'Tc', 'Eb', 'Nc', 'Ac', 'Wc', 'Aa', 'Ea', 'Nb', 'La', 'Wa', 'Td', 'Fd', 'Wa', 'Td', 'Lb', 'Ab', 'Wc', 'Nb', 'Ld', 'Lc', 'Wc', 'Nd', 'La', 'Wa', 'Wb', 'Td', 'Fa', 'Ed', 'Ab', 'Ec', 'Fd', 'Fa', 'Nc', 'Fc', 'Ac', 'Wa', 'Wa', 'Ab', 'Ea', 'Lc', 'Fa', 'Wa', 'Ea', 'Wa', 'Na', 'Wa', 'Aa', 'Wa', 'Tc', 'Ad', 'Lb', 'Lb', 'Ac', 'Lc', 'Ta', 'Na', 'Lc', 'Wa', 'Tc', 'Nb', 'Ea', 'Wd', 'Wc', 'Ab', 'Ac', 'Ad', 'Wb', 'Wb', 'Na', 'Nb', 'Nc', 'Wc', 'Ec', 'Nb', 'Wb', 'Wc', 'Ld', 'Fd', 'Nd', 'Wa', 'Ff', 'Wa', 'Lb', 'Wa', 'Tc', 'Fd', 'Wc', 'La', 'Wc', 'Lb', 'Na', 'Nb', 'Na', 'Wb', 'Ec', 'Wb', 'Tb', 'Fb', 'Nb', 'Ea', 'Aa', 'Tb', 'La', 'Ab', 'Ta', 'Tc', 'Fd', 'Na', 'Nb', 'Lb', 'Na', 'Wa', 'Wc', 'Ea', 'Wb', 'La', 'Ac', 'Wc', 'Wb', 'Aa', 'Fa', 'Wc', 'La', 'Eb', 'Wc', 'Nc', 'Lc', 'Wa', 'Wa', 'Fb', 'Wa', 'Fb', 'Aa', 'Na', 'Wc', 'La', 'Wb', 'Wa', 'Ac', 'Nb', 'Eb', 'Aa', 'Lb', 'Td', 'Ld', 'Ta', 'Lb', 'Ec', 'La', 'La', 'Fa', 'Nb', 'Ec', 'Nb', 'Wd', 'Wc', 'Ad', 'Wa', 'Fa', 'Ld', 'Nc', 'Ac', 'Nb', 'Wc', 'Ta', 'Nb', 'Wc', 'Na', 'Nc', 'Wb', 'Nb', 'Fd', 'Ab', 'Lb', 'Wc', 'Fd', 'Ad', 'Fa', 'Wa', 'Wc', 'Wa', 'Ac', 'Wc', 'Wa', 'Lb', 'Lc', 'Lb', 'Lc', 'Wa', 'Lb', 'La', 'Ab', 'Tb', 'La', 'Fa', 'Wb', 'Ac', 'Wb', 'Na', 'Ld', 'Tb', 'Tb', 'Wc', 'Wb', 'Wa', 'Ta', 'Lb', 'Lc', 'Td', 'Aa', 'Na', 'Wd', 'Nb', 'Nd', 'Ab', 'Ea', 'Ea', 'Ac', 'Fc', 'La', 'Fb', 'Wb', 'Wb', 'Aa', 'Aa', 'Wc', 'Nc', 'Wa', 'La', 'Lc', 'Wb', 'Fd', 'Ed', 'Ea', 'Aa', 'Fc', 'Ta', 'Ta', 'Ab', 'Nb', 'Nc', 'Ta', 'Lb', 'Nc', 'Td', 'Tc', 'Aa', 'Tb', 'Fd', 'Tb', 'Wb', 'Ea', 'Fb', 'Ea', 'La', 'Fc', 'Wb', 'Wa', 'Fe', 'Na', 'Fb', 'Wa', 'La', 'Nc', 'Wb', 'Fa', 'La', 'Wc', 'Tc', 'Ta', 'Wb', 'Wb', 'Ac', 'Aa', 'Wc', 'Ac', 'Ea', 'Ta', 'Wd', 'Eb', 'Eb', 'Ec', 'Ac', 'Lc', 'Tc', 'Na', 'Tc', 'Eb', 'Wb', 'Ld', 'Wc', 'Wa', 'Lc', 'Nb', 'Lb', 'Na', 'Ld', 'Nb', 'Tb', 'Fb', 'Tb', 'Wa', 'Nc', 'Na', 'Fb', 'Na', 'Wa', 'Eb', 'Na', 'Wc', 'Aa', 'Wc', 'Ld', 'Fa', 'Fa', 'Fc', 'Nb', 'Fa', 'Wb', 'Ld', 'Wc', 'Fd', 'Fd', 'Aa', 'Fc', 'La', 'Fb', 'Eb', 'Tc', 'Ab', 'Fe', 'Lb', 'Ta', 'Fd', 'Ec', 'Nb', 'Wb', 'Ec', 'Tc', 'Wa', 'Nb', 'Wd', 'Lc', 'Tc', 'Wa', 'Lb', 'Nc', 'Lc', 'La', 'Ab', 'Fd', 'La', 'Wa', 'Wb', 'Fa', 'Eb', 'Nb', 'Fb', 'Td', 'Ae', 'Ad', 'Td', 'Ed', 'Na', 'Wa', 'Tb', 'Nc', 'Fd', 'Lb', 'Ea', 'Lb', 'Eb', 'Fb', 'Wb', 'Ab', 'Wb', 'Ac', 'Aa', 'Ed', 'Ab', 'Wa', 'La', 'Wa', 'Ad', 'Wa', 'Fc', 'Wa', 'Ta', 'Ed', 'Aa', 'Ab', 'Aa', 'Wb', 'Nc', 'Wc', 'Ta', 'Aa', 'Ac', 'Ff', 'Fe', 'Lc', 'Lc', 'Tc', 'Nc', 'Ea', 'Fd', 'Fc', 'Ab', 'Na', 'Wb', 'Ac', 'Td', 'Wc', 'Ac', 'Ea', 'Nb', 'Fd', 'Tb', 'Ab', 'Wa', 'Wc', 'La', 'Lc', 'Nd', 'La', 'Wb', 'Ec', 'Ad', 'Wd', 'Ta', 'Ea', 'Fb', 'Nb', 'Ec', 'Fc', 'Wb', 'Wa', 'Ad', 'Nd']
#
#
# MODEL: byols
#
# The shape of the normalised embeddings array is: torch.Size([535, 2048])
# Normalised Embeddings Array:
# tensor([[-1.7335,  0.6622, -1.1219,  ...,  1.2875, -1.1183,  1.9438],
#         [-1.4622,  1.4331,  1.2716,  ..., -1.5948,  1.1460, -0.3171],
#         [-0.2498,  0.1551, -0.3696,  ...,  0.6349, -0.3390, -0.8454],
#         ...,
#         [ 0.2670, -0.4902,  0.3284,  ..., -0.2332, -0.6262, -0.8269],
#         [-1.9445, -1.1225, -1.6360,  ...,  1.1643, -0.6877,  0.1319],
#         [-0.8312, -1.0770,  0.5976,  ..., -0.1193,  0.1111,  0.4691]])
#
# Columnwise_mean:
# tensor([-2.6739e-09, -4.9021e-09, -2.2282e-09,  ...,  3.3423e-09,
#          3.5651e-09,  5.3477e-09])
# All means are less than 10**-6
#
#
# MODEL: compare
#
# The shape of the normalised embeddings array is: torch.Size([535, 6373])
# Normalised Embeddings Array:
# tensor([[-1.2518e+00, -9.8470e-01,  1.3664e+00,  ..., -2.6812e-01,
#          -8.1990e-01, -5.3719e-01],
#         [-1.0961e+00, -8.9370e-01,  1.5011e+00,  ..., -3.3849e-01,
#          -5.4847e-02,  2.6844e-01],
#         [-9.3700e-01, -7.7461e-01, -9.9005e-02,  ..., -6.1882e-01,
#          -8.6754e-01, -9.2066e-01],
#         ...,
#         [ 5.2417e-02,  1.7052e-03, -8.3639e-01,  ...,  6.4183e-02,
#           2.7610e-01,  3.8570e-01],
#         [-1.4567e-01,  1.4054e+00, -1.3950e+00,  ...,  2.6115e-01,
#           1.0994e+00,  2.0869e-01],
#         [-2.0924e+00, -1.1916e+00, -1.7075e-01,  ...,  2.3763e-01,
#          -1.2713e+00, -1.1388e+00]])
#
# Columnwise_mean:
# tensor([-4.4564e-10,  0.0000e+00, -1.7826e-09,  ...,  1.7826e-09,
#          1.3369e-09, -2.6739e-09])
# All means are less than 10**-6
#
#
# MODEL: egemaps
#
# The shape of the normalised embeddings array is: torch.Size([535, 88])
# Normalised Embeddings Array:
# tensor([[-1.9743,  1.3976, -2.2510,  ...,  1.3403,  2.4832, -0.1912],
#         [-0.7059, -0.4500, -0.6256,  ..., -0.3390, -0.1284,  1.6586],
#         [-0.6300,  0.1034, -0.6051,  ..., -0.7573, -0.5452,  0.4289],
#         ...,
#         [ 0.5479,  0.9222,  0.2216,  ..., -1.0166, -0.6702, -2.1521],
#         [-0.3208,  1.2238, -0.4323,  ..., -0.6024, -0.2510, -0.0533],
#         [-1.5792,  1.0941, -1.4990,  ...,  0.1232,  0.1003,  0.1583]])
#
# Columnwise_mean:
# tensor([-2.2282e-09, -4.4564e-09, -4.4564e-10, -1.7826e-09,  1.7826e-09,
#         -5.3477e-09,  5.3477e-09,  5.3477e-09,  7.1303e-09, -8.9128e-10,
#          0.0000e+00,  8.9128e-10,  3.5651e-09, -1.3369e-09,  4.4564e-10,
#          1.7826e-09,  7.1303e-09,  0.0000e+00, -3.5651e-09,  1.7826e-09,
#         -2.7853e-09, -4.4564e-09,  4.4564e-10, -3.5651e-09, -7.1303e-09,
#          4.4564e-10, -3.5651e-09, -3.3423e-09,  6.6846e-10, -3.5651e-09,
#          6.6846e-10, -3.5651e-09, -3.5651e-09,  2.2282e-09, -3.5651e-09,
#          4.4564e-09,  4.0108e-09,  1.7826e-09,  8.9128e-10, -4.4564e-09,
#          8.9128e-10, -1.7826e-09,  8.9128e-10, -8.9128e-10,  2.2282e-09,
#         -9.8041e-09,  8.9128e-10, -5.1249e-09,  4.4564e-09, -3.6765e-09,
#          4.4564e-10,  7.3531e-09, -1.7826e-09,  3.5651e-09,  0.0000e+00,
#          1.7826e-09, -2.4510e-09,  1.3369e-09,  1.3369e-09,  3.3423e-09,
#         -2.4510e-09, -3.5651e-09, -6.2390e-09, -1.7826e-09, -3.5651e-09,
#          0.0000e+00, -1.7826e-09, -3.5651e-09, -1.7826e-09, -1.7826e-09,
#         -3.1195e-09, -1.3369e-09,  1.7826e-09,  0.0000e+00,  3.5651e-09,
#          3.5651e-09,  4.4564e-10, -4.0108e-09,  3.5651e-09,  0.0000e+00,
#          3.5651e-09,  8.9128e-10,  0.0000e+00,  4.4564e-09, -4.4564e-09,
#         -3.5651e-09, -7.1303e-09, -8.9128e-10])
# All means are less than 10**-6

# %%
# Phase_3

# Train Test splitting
# X_train_wav2vec, X_test_wav2vec, y_train_wav2vec, y_test_wav2vec = split_train_test(normalised_embeddings_wav2vec, labels, test_size = 0.30)
# X_train_hubert, X_test_hubert, y_train_hubert, y_test_hubert = split_train_test(normalised_embeddings_hubert, labels, test_size = 0.30)
X_train_byols, X_test_byols, y_train_byols, y_test_byols = split_train_test(normalised_embeddings_byols, labels, test_size = 0.30)
X_train_compare, X_test_compare, y_train_compare, y_test_compare = split_train_test(normalised_embeddings_compare, labels, test_size = 0.30)
X_train_egemaps, X_test_egemaps, y_train_egemaps, y_test_egemaps = split_train_test(normalised_embeddings_egemaps, labels, test_size = 0.30)

# Verify
for i in range(len(models)):
  print()
  print()
  print('MODEL: {}'.format(models[i]))
  print()
  X_train, X_test, y_train, y_test = split_train_test(normalised_embeddings_arrays[i], labels, test_size = 0.30)
  print('The shape of X_train is: {}'.format(X_train.shape))
  print('X_train')
  print(X_train)
  print()
  print('The shape of X_test is: {}'.format(X_test.shape))
  print('X_test')
  print(X_test)
  print()
  print('The length of y_train is: {}'.format(len(y_train)))
  print('y_train')
  print(y_train)
  print()
  print('The length of y_test is: {}'.format(len(y_test)))
  print('y_test')
  print(y_test)
# Out:
# MODEL: byols
#
# The shape of X_train is: torch.Size([374, 2048])
# X_train
# tensor([[ 2.8226e-01,  3.3452e+00,  8.1016e-01,  ...,  1.2256e-01,
#          -1.7933e-01, -1.1523e+00],
#         [-3.9343e-02,  1.7592e+00, -7.0430e-01,  ...,  6.9959e-01,
#           1.1014e+00,  6.0119e-01],
#         [ 1.3394e+00,  5.6732e-02, -4.5411e-02,  ..., -9.6064e-01,
#          -8.1373e-01,  1.8339e-02],
#         ...,
#         [-2.0256e+00,  1.1691e+00, -9.3264e-01,  ..., -1.0528e+00,
#           1.4449e+00,  1.3276e+00],
#         [-1.1762e+00,  6.9049e-04, -3.6890e-01,  ..., -5.2358e-01,
#           4.1650e-01,  3.3237e+00],
#         [ 9.7718e-01,  1.6894e+00,  2.5897e+00,  ...,  9.0606e-01,
#          -8.5933e-01,  5.4565e-01]])
#
# The shape of X_test is: torch.Size([161, 2048])
# X_test
# tensor([[ 1.2725, -1.4142,  0.5159,  ...,  0.7724,  1.2364, -0.9796],
#         [ 1.0047,  0.7296, -0.5194,  ..., -0.1874, -0.2266,  0.8707],
#         [-1.7569, -0.7789,  0.9907,  ...,  0.5762,  0.5052,  1.3295],
#         ...,
#         [ 1.1123, -1.1713, -0.0875,  ..., -1.0034, -0.0051, -1.1518],
#         [-0.1070, -1.1855, -0.6850,  ...,  1.2022,  1.0777, -1.0220],
#         [ 0.5701,  1.3034, -0.0858,  ...,  2.4735,  0.5411, -1.3242]])
#
# The length of y_train is: 374
# y_train
# ['Wa', 'Ec', 'Wa', 'Td', 'Wa', 'Ta', 'Ta', 'Fc', 'Lc', 'Na', 'Fa', 'Lb', 'Fb', 'Na', 'Nd', 'Wb', 'Lc', 'Ea', 'Fa', 'Nd', 'Wa', 'Na', 'Tc', 'Nc', 'Wa', 'Ab', 'Lc', 'Fd', 'Td', 'Aa', 'La', 'Fa', 'Ad', 'Td', 'Wb', 'Wc', 'Fc', 'Fd', 'Tc', 'Tb', 'Lb', 'Ac', 'Wc', 'Ad', 'Ad', 'Ac', 'Tb', 'Aa', 'Tb', 'Lc', 'Aa', 'Ec', 'Wc', 'La', 'Nb', 'Wa', 'Td', 'Wb', 'Fb', 'Lb', 'Nb', 'Tb', 'Fd', 'Nd', 'Td', 'Wd', 'Ea', 'Wc', 'Na', 'La', 'Ld', 'La', 'Wb', 'Ea', 'Ea', 'Ff', 'Wa', 'Ac', 'La', 'Wc', 'Fd', 'Eb', 'Wa', 'Ab', 'Nd', 'Wb', 'Wb', 'La', 'Lc', 'Ta', 'Ed', 'Ea', 'Ab', 'Wb', 'Nb', 'Wc', 'Nc', 'Ld', 'Wa', 'Ea', 'Ed', 'Fc', 'Wc', 'Ec', 'Ac', 'Ta', 'Ta', 'La', 'Wb', 'Wc', 'Wa', 'Na', 'Na', 'Ad', 'Nb', 'Wb', 'Tc', 'Tb', 'Fb', 'La', 'Ab', 'Ea', 'La', 'Wa', 'Ae', 'Tb', 'Na', 'Wa', 'Ab', 'Wb', 'Aa', 'Wc', 'Fa', 'Ab', 'Ac', 'Fb', 'Wa', 'Ad', 'Tc', 'Wc', 'Wc', 'Wc', 'Fd', 'Eb', 'Ta', 'Nb', 'Wb', 'La', 'Wa', 'Nb', 'La', 'Aa', 'Tc', 'Ta', 'La', 'Ac', 'Wa', 'Aa', 'Lc', 'La', 'Ab', 'Fa', 'Lb', 'Ea', 'Nc', 'Fb', 'Ab', 'Wa', 'Lc', 'Nb', 'Fc', 'Wd', 'Fc', 'La', 'Lb', 'Nc', 'Wa', 'Ac', 'Wb', 'Tc', 'Lc', 'Wa', 'Eb', 'Eb', 'Tb', 'Aa', 'Ec', 'Lc', 'Nd', 'Ab', 'Wa', 'Wb', 'Wc', 'Lb', 'Ea', 'Wb', 'Wc', 'Ac', 'Fd', 'Aa', 'Ac', 'La', 'Wc', 'Wb', 'Ea', 'Wd', 'Fa', 'Wc', 'Td', 'Fd', 'Eb', 'Ld', 'Wc', 'La', 'Aa', 'Wb', 'Wa', 'Wb', 'Ff', 'Fd', 'Nb', 'La', 'Tb', 'Wb', 'Wc', 'Eb', 'Fe', 'Nb', 'Wc', 'Ac', 'Wa', 'Ad', 'Lb', 'Na', 'Lb', 'Wc', 'Fb', 'Na', 'Ac', 'Fd', 'Lc', 'Ec', 'Ab', 'Ta', 'Tc', 'Fa', 'Na', 'Lb', 'Tc', 'Wb', 'Ld', 'Na', 'Ta', 'Tc', 'Nc', 'Wc', 'Fe', 'Na', 'Aa', 'Ta', 'Td', 'Ta', 'Nc', 'Na', 'Na', 'Lc', 'Ed', 'Lb', 'Fd', 'Wc', 'Wa', 'Ac', 'Wc', 'Ta', 'Aa', 'Wc', 'La', 'Na', 'Fc', 'Wc', 'Lb', 'Ec', 'Wb', 'Fb', 'Ec', 'Fb', 'Wc', 'Td', 'Wa', 'Nc', 'Nb', 'Fd', 'Tb', 'Fa', 'Nc', 'Lb', 'Nc', 'La', 'Nb', 'Fb', 'Na', 'Wa', 'Fd', 'Ea', 'Wb', 'Ac', 'La', 'Wa', 'Lb', 'Na', 'Wa', 'Wb', 'Wa', 'Aa', 'Lb', 'Wd', 'Lb', 'Tb', 'Ac', 'Td', 'Nc', 'Nb', 'Tb', 'Fe', 'Nc', 'Lb', 'Nb', 'Na', 'Ec', 'Nd', 'Wc', 'Td', 'Wa', 'Wc', 'Wd', 'Ad', 'Td', 'La', 'Nb', 'Lc', 'Ab', 'Fa', 'Nc', 'Ea', 'Fb', 'Wb', 'Na', 'Ac', 'Tb', 'Wb', 'Aa', 'Tc', 'Nb', 'Wa', 'Fc', 'Wa', 'Ab', 'Aa', 'Nc', 'Wc', 'Ad', 'Fb', 'Wa', 'Fa', 'Wa', 'Lb', 'Lc', 'Lb', 'Wc', 'Fc', 'Tc', 'Tc', 'Nb', 'Eb']
#
# The length of y_test is: 161
# y_test
# ['Wc', 'Fe', 'Ld', 'Na', 'Wa', 'Fc', 'Fb', 'Ab', 'Wc', 'Wb', 'Lb', 'Tb', 'Eb', 'Ta', 'Nc', 'Lc', 'Ec', 'Lb', 'Wb', 'Eb', 'Wd', 'Ec', 'Ad', 'Wa', 'Na', 'Aa', 'Ta', 'Wb', 'Eb', 'Wa', 'Na', 'Fd', 'Wd', 'Tb', 'Ac', 'Wa', 'Nb', 'Wa', 'Nd', 'Fa', 'Wa', 'Wd', 'La', 'Ea', 'Fb', 'Lb', 'Wb', 'Wb', 'Fa', 'Fd', 'Wb', 'Ea', 'Nb', 'Lb', 'Nb', 'Wa', 'Lc', 'Wd', 'Fb', 'Lc', 'Eb', 'Nc', 'Wb', 'Wc', 'Wb', 'Fd', 'Ta', 'La', 'Wb', 'Wb', 'Ec', 'Fb', 'Nc', 'Tc', 'Nb', 'Wb', 'Ac', 'Ad', 'Wb', 'Wa', 'Ab', 'Ac', 'Tc', 'Nb', 'Nb', 'Nb', 'Fd', 'Fd', 'Fd', 'Nb', 'Wc', 'Fc', 'Fa', 'La', 'Aa', 'Nc', 'Fc', 'Ea', 'Fa', 'Fd', 'Ld', 'Ea', 'Nb', 'Na', 'Wb', 'Wb', 'Ab', 'Na', 'Ab', 'Aa', 'Wc', 'Ld', 'Tc', 'Ta', 'Ea', 'Tc', 'Aa', 'Lb', 'La', 'Tc', 'Na', 'Ed', 'La', 'Ac', 'Wc', 'Fa', 'Nc', 'La', 'Fa', 'Wa', 'Tb', 'Lb', 'Ta', 'Lb', 'Tc', 'Wb', 'Aa', 'Ac', 'Eb', 'Ld', 'Fd', 'Nb', 'Fc', 'Lc', 'Ld', 'Aa', 'Aa', 'Wa', 'Ed', 'Lb', 'Ld', 'Lb', 'Nc', 'Ta', 'Na', 'Fc', 'Wa', 'Ea', 'Fa', 'Nc', 'Ad']
#
#
# MODEL: compare
#
# The shape of X_train is: torch.Size([374, 6373])
# X_train
# tensor([[ 0.6793,  1.3272,  1.4755,  ...,  0.4760,  1.4139,  1.6333],
#         [ 1.7529, -0.9667, -0.8591,  ..., -0.3604,  0.0465, -0.3811],
#         [ 0.8193, -0.4299, -0.8697,  ...,  0.1383,  0.2346, -0.0130],
#         ...,
#         [ 0.1301, -0.2687, -0.8701,  ..., -1.0887, -1.3318, -0.7919],
#         [-0.7120, -1.5382,  1.4128,  ..., -1.0420, -0.0659,  0.2942],
#         [ 0.2384,  0.9120,  0.1843,  ..., -0.2421, -0.2503, -0.9575]])
#
# The shape of X_test is: torch.Size([161, 6373])
# X_test
# tensor([[ 1.0059,  1.7690, -0.9572,  ...,  0.5092,  0.8511,  0.7925],
#         [ 1.0085, -0.7178, -1.0328,  ..., -0.1550,  0.9257,  0.1715],
#         [ 0.1581, -0.7854, -0.2067,  ...,  0.6049, -0.9059,  0.3191],
#         ...,
#         [ 1.1064, -0.5420,  1.6354,  ...,  0.6158,  1.3372,  1.3840],
#         [ 0.0887, -0.5873, -0.8376,  ..., -1.1110,  0.1424, -1.1134],
#         [ 0.1121, -0.8211, -0.7921,  ..., -0.1506,  0.8447, -0.3957]])
#
# The length of y_train is: 374
# y_train
# ['Wa', 'Ec', 'Wa', 'Td', 'Wa', 'Ta', 'Ta', 'Fc', 'Lc', 'Na', 'Fa', 'Lb', 'Fb', 'Na', 'Nd', 'Wb', 'Lc', 'Ea', 'Fa', 'Nd', 'Wa', 'Na', 'Tc', 'Nc', 'Wa', 'Ab', 'Lc', 'Fd', 'Td', 'Aa', 'La', 'Fa', 'Ad', 'Td', 'Wb', 'Wc', 'Fc', 'Fd', 'Tc', 'Tb', 'Lb', 'Ac', 'Wc', 'Ad', 'Ad', 'Ac', 'Tb', 'Aa', 'Tb', 'Lc', 'Aa', 'Ec', 'Wc', 'La', 'Nb', 'Wa', 'Td', 'Wb', 'Fb', 'Lb', 'Nb', 'Tb', 'Fd', 'Nd', 'Td', 'Wd', 'Ea', 'Wc', 'Na', 'La', 'Ld', 'La', 'Wb', 'Ea', 'Ea', 'Ff', 'Wa', 'Ac', 'La', 'Wc', 'Fd', 'Eb', 'Wa', 'Ab', 'Nd', 'Wb', 'Wb', 'La', 'Lc', 'Ta', 'Ed', 'Ea', 'Ab', 'Wb', 'Nb', 'Wc', 'Nc', 'Ld', 'Wa', 'Ea', 'Ed', 'Fc', 'Wc', 'Ec', 'Ac', 'Ta', 'Ta', 'La', 'Wb', 'Wc', 'Wa', 'Na', 'Na', 'Ad', 'Nb', 'Wb', 'Tc', 'Tb', 'Fb', 'La', 'Ab', 'Ea', 'La', 'Wa', 'Ae', 'Tb', 'Na', 'Wa', 'Ab', 'Wb', 'Aa', 'Wc', 'Fa', 'Ab', 'Ac', 'Fb', 'Wa', 'Ad', 'Tc', 'Wc', 'Wc', 'Wc', 'Fd', 'Eb', 'Ta', 'Nb', 'Wb', 'La', 'Wa', 'Nb', 'La', 'Aa', 'Tc', 'Ta', 'La', 'Ac', 'Wa', 'Aa', 'Lc', 'La', 'Ab', 'Fa', 'Lb', 'Ea', 'Nc', 'Fb', 'Ab', 'Wa', 'Lc', 'Nb', 'Fc', 'Wd', 'Fc', 'La', 'Lb', 'Nc', 'Wa', 'Ac', 'Wb', 'Tc', 'Lc', 'Wa', 'Eb', 'Eb', 'Tb', 'Aa', 'Ec', 'Lc', 'Nd', 'Ab', 'Wa', 'Wb', 'Wc', 'Lb', 'Ea', 'Wb', 'Wc', 'Ac', 'Fd', 'Aa', 'Ac', 'La', 'Wc', 'Wb', 'Ea', 'Wd', 'Fa', 'Wc', 'Td', 'Fd', 'Eb', 'Ld', 'Wc', 'La', 'Aa', 'Wb', 'Wa', 'Wb', 'Ff', 'Fd', 'Nb', 'La', 'Tb', 'Wb', 'Wc', 'Eb', 'Fe', 'Nb', 'Wc', 'Ac', 'Wa', 'Ad', 'Lb', 'Na', 'Lb', 'Wc', 'Fb', 'Na', 'Ac', 'Fd', 'Lc', 'Ec', 'Ab', 'Ta', 'Tc', 'Fa', 'Na', 'Lb', 'Tc', 'Wb', 'Ld', 'Na', 'Ta', 'Tc', 'Nc', 'Wc', 'Fe', 'Na', 'Aa', 'Ta', 'Td', 'Ta', 'Nc', 'Na', 'Na', 'Lc', 'Ed', 'Lb', 'Fd', 'Wc', 'Wa', 'Ac', 'Wc', 'Ta', 'Aa', 'Wc', 'La', 'Na', 'Fc', 'Wc', 'Lb', 'Ec', 'Wb', 'Fb', 'Ec', 'Fb', 'Wc', 'Td', 'Wa', 'Nc', 'Nb', 'Fd', 'Tb', 'Fa', 'Nc', 'Lb', 'Nc', 'La', 'Nb', 'Fb', 'Na', 'Wa', 'Fd', 'Ea', 'Wb', 'Ac', 'La', 'Wa', 'Lb', 'Na', 'Wa', 'Wb', 'Wa', 'Aa', 'Lb', 'Wd', 'Lb', 'Tb', 'Ac', 'Td', 'Nc', 'Nb', 'Tb', 'Fe', 'Nc', 'Lb', 'Nb', 'Na', 'Ec', 'Nd', 'Wc', 'Td', 'Wa', 'Wc', 'Wd', 'Ad', 'Td', 'La', 'Nb', 'Lc', 'Ab', 'Fa', 'Nc', 'Ea', 'Fb', 'Wb', 'Na', 'Ac', 'Tb', 'Wb', 'Aa', 'Tc', 'Nb', 'Wa', 'Fc', 'Wa', 'Ab', 'Aa', 'Nc', 'Wc', 'Ad', 'Fb', 'Wa', 'Fa', 'Wa', 'Lb', 'Lc', 'Lb', 'Wc', 'Fc', 'Tc', 'Tc', 'Nb', 'Eb']
#
# The length of y_test is: 161
# y_test
# ['Wc', 'Fe', 'Ld', 'Na', 'Wa', 'Fc', 'Fb', 'Ab', 'Wc', 'Wb', 'Lb', 'Tb', 'Eb', 'Ta', 'Nc', 'Lc', 'Ec', 'Lb', 'Wb', 'Eb', 'Wd', 'Ec', 'Ad', 'Wa', 'Na', 'Aa', 'Ta', 'Wb', 'Eb', 'Wa', 'Na', 'Fd', 'Wd', 'Tb', 'Ac', 'Wa', 'Nb', 'Wa', 'Nd', 'Fa', 'Wa', 'Wd', 'La', 'Ea', 'Fb', 'Lb', 'Wb', 'Wb', 'Fa', 'Fd', 'Wb', 'Ea', 'Nb', 'Lb', 'Nb', 'Wa', 'Lc', 'Wd', 'Fb', 'Lc', 'Eb', 'Nc', 'Wb', 'Wc', 'Wb', 'Fd', 'Ta', 'La', 'Wb', 'Wb', 'Ec', 'Fb', 'Nc', 'Tc', 'Nb', 'Wb', 'Ac', 'Ad', 'Wb', 'Wa', 'Ab', 'Ac', 'Tc', 'Nb', 'Nb', 'Nb', 'Fd', 'Fd', 'Fd', 'Nb', 'Wc', 'Fc', 'Fa', 'La', 'Aa', 'Nc', 'Fc', 'Ea', 'Fa', 'Fd', 'Ld', 'Ea', 'Nb', 'Na', 'Wb', 'Wb', 'Ab', 'Na', 'Ab', 'Aa', 'Wc', 'Ld', 'Tc', 'Ta', 'Ea', 'Tc', 'Aa', 'Lb', 'La', 'Tc', 'Na', 'Ed', 'La', 'Ac', 'Wc', 'Fa', 'Nc', 'La', 'Fa', 'Wa', 'Tb', 'Lb', 'Ta', 'Lb', 'Tc', 'Wb', 'Aa', 'Ac', 'Eb', 'Ld', 'Fd', 'Nb', 'Fc', 'Lc', 'Ld', 'Aa', 'Aa', 'Wa', 'Ed', 'Lb', 'Ld', 'Lb', 'Nc', 'Ta', 'Na', 'Fc', 'Wa', 'Ea', 'Fa', 'Nc', 'Ad']
#
#
# MODEL: egemaps
#
# The shape of X_train is: torch.Size([374, 88])
# X_train
# tensor([[ 1.1734e+00, -2.3897e-01,  1.2222e+00,  ...,  8.6425e-02,
#           9.0751e-02, -5.7327e-01],
#         [ 1.1225e-02, -8.8428e-01,  4.3710e-02,  ...,  1.9236e+00,
#           1.7785e+00,  6.2184e-01],
#         [ 1.0738e+00, -6.1524e-01,  1.1510e+00,  ..., -8.6196e-01,
#          -6.3265e-01,  5.4531e-02],
#         ...,
#         [-2.9631e-01,  2.9956e+00, -6.0832e-01,  ...,  1.5902e+00,
#           3.5009e+00,  1.3469e+00],
#         [-1.1373e+00, -1.5795e-01, -1.0747e+00,  ...,  7.0075e-02,
#           1.1282e-01, -5.5470e-01],
#         [ 9.5891e-03, -2.3194e-01, -3.4073e-04,  ...,  5.8549e-01,
#           4.9837e-01, -2.6985e-02]])
#
# The shape of X_test is: torch.Size([161, 88])
# X_test
# tensor([[ 1.1148e+00, -1.6232e-01,  9.6885e-01,  ..., -6.5525e-01,
#          -6.6726e-01, -7.0413e-01],
#         [ 8.6166e-01, -1.2656e+00,  1.0954e+00,  ..., -4.0442e-01,
#          -4.5169e-01,  1.7874e-01],
#         [-1.5208e-01,  3.4349e+00, -1.2197e+00,  ...,  1.0371e-01,
#           3.3465e-01,  1.5982e+00],
#         ...,
#         [ 9.0915e-01,  5.2122e-01,  5.2952e-01,  ..., -1.2357e+00,
#          -9.3143e-01,  1.9019e-01],
#         [-1.0082e+00,  2.2365e-01, -1.1044e+00,  ..., -6.8727e-01,
#          -6.0650e-01,  6.7632e-01],
#         [ 1.2346e+00, -1.2195e+00,  1.4770e+00,  ..., -9.7507e-01,
#          -6.5114e-01, -2.0664e-03]])
#
# The length of y_train is: 374
# y_train
# ['Wa', 'Ec', 'Wa', 'Td', 'Wa', 'Ta', 'Ta', 'Fc', 'Lc', 'Na', 'Fa', 'Lb', 'Fb', 'Na', 'Nd', 'Wb', 'Lc', 'Ea', 'Fa', 'Nd', 'Wa', 'Na', 'Tc', 'Nc', 'Wa', 'Ab', 'Lc', 'Fd', 'Td', 'Aa', 'La', 'Fa', 'Ad', 'Td', 'Wb', 'Wc', 'Fc', 'Fd', 'Tc', 'Tb', 'Lb', 'Ac', 'Wc', 'Ad', 'Ad', 'Ac', 'Tb', 'Aa', 'Tb', 'Lc', 'Aa', 'Ec', 'Wc', 'La', 'Nb', 'Wa', 'Td', 'Wb', 'Fb', 'Lb', 'Nb', 'Tb', 'Fd', 'Nd', 'Td', 'Wd', 'Ea', 'Wc', 'Na', 'La', 'Ld', 'La', 'Wb', 'Ea', 'Ea', 'Ff', 'Wa', 'Ac', 'La', 'Wc', 'Fd', 'Eb', 'Wa', 'Ab', 'Nd', 'Wb', 'Wb', 'La', 'Lc', 'Ta', 'Ed', 'Ea', 'Ab', 'Wb', 'Nb', 'Wc', 'Nc', 'Ld', 'Wa', 'Ea', 'Ed', 'Fc', 'Wc', 'Ec', 'Ac', 'Ta', 'Ta', 'La', 'Wb', 'Wc', 'Wa', 'Na', 'Na', 'Ad', 'Nb', 'Wb', 'Tc', 'Tb', 'Fb', 'La', 'Ab', 'Ea', 'La', 'Wa', 'Ae', 'Tb', 'Na', 'Wa', 'Ab', 'Wb', 'Aa', 'Wc', 'Fa', 'Ab', 'Ac', 'Fb', 'Wa', 'Ad', 'Tc', 'Wc', 'Wc', 'Wc', 'Fd', 'Eb', 'Ta', 'Nb', 'Wb', 'La', 'Wa', 'Nb', 'La', 'Aa', 'Tc', 'Ta', 'La', 'Ac', 'Wa', 'Aa', 'Lc', 'La', 'Ab', 'Fa', 'Lb', 'Ea', 'Nc', 'Fb', 'Ab', 'Wa', 'Lc', 'Nb', 'Fc', 'Wd', 'Fc', 'La', 'Lb', 'Nc', 'Wa', 'Ac', 'Wb', 'Tc', 'Lc', 'Wa', 'Eb', 'Eb', 'Tb', 'Aa', 'Ec', 'Lc', 'Nd', 'Ab', 'Wa', 'Wb', 'Wc', 'Lb', 'Ea', 'Wb', 'Wc', 'Ac', 'Fd', 'Aa', 'Ac', 'La', 'Wc', 'Wb', 'Ea', 'Wd', 'Fa', 'Wc', 'Td', 'Fd', 'Eb', 'Ld', 'Wc', 'La', 'Aa', 'Wb', 'Wa', 'Wb', 'Ff', 'Fd', 'Nb', 'La', 'Tb', 'Wb', 'Wc', 'Eb', 'Fe', 'Nb', 'Wc', 'Ac', 'Wa', 'Ad', 'Lb', 'Na', 'Lb', 'Wc', 'Fb', 'Na', 'Ac', 'Fd', 'Lc', 'Ec', 'Ab', 'Ta', 'Tc', 'Fa', 'Na', 'Lb', 'Tc', 'Wb', 'Ld', 'Na', 'Ta', 'Tc', 'Nc', 'Wc', 'Fe', 'Na', 'Aa', 'Ta', 'Td', 'Ta', 'Nc', 'Na', 'Na', 'Lc', 'Ed', 'Lb', 'Fd', 'Wc', 'Wa', 'Ac', 'Wc', 'Ta', 'Aa', 'Wc', 'La', 'Na', 'Fc', 'Wc', 'Lb', 'Ec', 'Wb', 'Fb', 'Ec', 'Fb', 'Wc', 'Td', 'Wa', 'Nc', 'Nb', 'Fd', 'Tb', 'Fa', 'Nc', 'Lb', 'Nc', 'La', 'Nb', 'Fb', 'Na', 'Wa', 'Fd', 'Ea', 'Wb', 'Ac', 'La', 'Wa', 'Lb', 'Na', 'Wa', 'Wb', 'Wa', 'Aa', 'Lb', 'Wd', 'Lb', 'Tb', 'Ac', 'Td', 'Nc', 'Nb', 'Tb', 'Fe', 'Nc', 'Lb', 'Nb', 'Na', 'Ec', 'Nd', 'Wc', 'Td', 'Wa', 'Wc', 'Wd', 'Ad', 'Td', 'La', 'Nb', 'Lc', 'Ab', 'Fa', 'Nc', 'Ea', 'Fb', 'Wb', 'Na', 'Ac', 'Tb', 'Wb', 'Aa', 'Tc', 'Nb', 'Wa', 'Fc', 'Wa', 'Ab', 'Aa', 'Nc', 'Wc', 'Ad', 'Fb', 'Wa', 'Fa', 'Wa', 'Lb', 'Lc', 'Lb', 'Wc', 'Fc', 'Tc', 'Tc', 'Nb', 'Eb']
#
# The length of y_test is: 161
# y_test
# ['Wc', 'Fe', 'Ld', 'Na', 'Wa', 'Fc', 'Fb', 'Ab', 'Wc', 'Wb', 'Lb', 'Tb', 'Eb', 'Ta', 'Nc', 'Lc', 'Ec', 'Lb', 'Wb', 'Eb', 'Wd', 'Ec', 'Ad', 'Wa', 'Na', 'Aa', 'Ta', 'Wb', 'Eb', 'Wa', 'Na', 'Fd', 'Wd', 'Tb', 'Ac', 'Wa', 'Nb', 'Wa', 'Nd', 'Fa', 'Wa', 'Wd', 'La', 'Ea', 'Fb', 'Lb', 'Wb', 'Wb', 'Fa', 'Fd', 'Wb', 'Ea', 'Nb', 'Lb', 'Nb', 'Wa', 'Lc', 'Wd', 'Fb', 'Lc', 'Eb', 'Nc', 'Wb', 'Wc', 'Wb', 'Fd', 'Ta', 'La', 'Wb', 'Wb', 'Ec', 'Fb', 'Nc', 'Tc', 'Nb', 'Wb', 'Ac', 'Ad', 'Wb', 'Wa', 'Ab', 'Ac', 'Tc', 'Nb', 'Nb', 'Nb', 'Fd', 'Fd', 'Fd', 'Nb', 'Wc', 'Fc', 'Fa', 'La', 'Aa', 'Nc', 'Fc', 'Ea', 'Fa', 'Fd', 'Ld', 'Ea', 'Nb', 'Na', 'Wb', 'Wb', 'Ab', 'Na', 'Ab', 'Aa', 'Wc', 'Ld', 'Tc', 'Ta', 'Ea', 'Tc', 'Aa', 'Lb', 'La', 'Tc', 'Na', 'Ed', 'La', 'Ac', 'Wc', 'Fa', 'Nc', 'La', 'Fa', 'Wa', 'Tb', 'Lb', 'Ta', 'Lb', 'Tc', 'Wb', 'Aa', 'Ac', 'Eb', 'Ld', 'Fd', 'Nb', 'Fc', 'Lc', 'Ld', 'Aa', 'Aa', 'Wa', 'Ed', 'Lb', 'Ld', 'Lb', 'Nc', 'Ta', 'Na', 'Fc', 'Wa', 'Ea', 'Fa', 'Nc', 'Ad']
